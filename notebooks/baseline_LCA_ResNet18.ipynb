# %%
import os
import json
from pathlib import Path
from tqdm import tqdm
import datetime as dt
import logging

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from PIL import Image

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, balanced_accuracy_score, f1_score, precision_score, recall_score

from torchvision.transforms import v2
from torch.utils.data import Dataset, DataLoader 

import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models 
from torchvision.models import ResNet18_Weights

from sklearn.model_selection import StratifiedGroupKFold

# %% [markdown]
# LCA, эксперимент, который выполнялся при определении параметров.
#
# Model: `ResNet-18`
#
# Parameters:
# - Batch_size: 16
# - Optimizer: RMSProp
# - LR: 1e-4
#
# Полученные метрики (из статьи):
# * F1: 0.800 +- 0.021
# * Balanced Accuracy: 0.623 +- 0.017
# * Accuracy: 0.708 +- 0.023

# %%
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

SEED = 42
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

BATCH_SIZE = 16
LR = 1e-4
EPOCHS = 10

CV_N = 5
STEP_BATCH_LOG = 10

input_img_shape = (3,224,224)
split_level = "video_id"


path2model_save = Path("../models_checkpoints")
os.makedirs(path2model_save, exist_ok=True)

model_name = "resnet_18_backbone_cv" # model train name
prefix_train = "full_tuning_patient" # prefix train


comment = f""" 
===== general parameters =====
SEED: {SEED}
DEVICE: {DEVICE}

BATCH_SIZE: {BATCH_SIZE}
input_img_shape: {input_img_shape}
split_level: {split_level}

===== train parameters =====

LR: {LR}


CV_N: {CV_N}
EPOCHS: {EPOCHS}
STEP_BATCH_LOG: {STEP_BATCH_LOG}

===== about model and save =====
base_dir_for_model_save: {path2model_save}

model_name: {model_name}
prefix_train: {prefix_train}

===== comments =====
LCA
cross-validation
split patient level
SGDM optimizer
use augmentation
use ImageNet stats for (mean, std) normalization 
"""

# %% [markdown]
# ### Загрузка датасета

# %%
df_nonleison_metadata = pd.read_csv("../data/lca_nonleison_metadata_aug.csv")
df_leison_metadata = pd.read_csv("../data/lca_leison_metadata_aug.csv")

df_test_metadeta = pd.read_csv("../data/lca_test.csv")

# === Объединяем фреймы (Нужно перемешать) ===
df_train = pd.concat([df_nonleison_metadata, df_leison_metadata], ignore_index=True)

# %% [markdown]
# ### Model architecture - ResNet-18

# %%
class ResNet_18_Backbone(nn.Module):
    def __init__(self, img_size: tuple[int, int, int], out_classes: int, freeze_backbone: bool = True):
        super().__init__()

        self.in_channels = img_size[0]
        self.img_size = img_size
        self.out_classes = out_classes
        self.freeze_backbone = freeze_backbone
        
        self.backbone = models.resnet18(weights=ResNet18_Weights.IMAGENET1K_V1)
        
        num_features = self.backbone.fc.in_features
        self.backbone.fc = nn.Linear(num_features, self.out_classes)
        
        if self.freeze_backbone:
            for param in self.backbone.parameters():
                param.requires_grad = False

    def forward(self, x: torch.Tensor):
        out = self.backbone(x)
        return out

# %% [markdown]
# ### Dataset

# %%
class CADICADataset(Dataset):
    def __init__(self, dataframe: pd.DataFrame, img_path_col: str, label_col: str, transform = None):
        self.dataframe = dataframe
        self.img_path_col = img_path_col
        self.label_col = label_col
        self.transform = transform

    def __len__(self):
        return self.dataframe.shape[0]

    def __getitem__(self, idx):
        path_to_img = self.dataframe.loc[idx, self.img_path_col]
        image = Image.open(path_to_img).convert("RGB")
        label = self.dataframe.loc[idx, self.label_col]
        if self.transform:
            image = self.transform(image)
        return image, label

# %%
def create_logger(dir_for_save: str, log_file: str):
    
    full_path2save = f"{dir_for_save}/{log_file}"

    logger = logging.getLogger("ModelTrainer")
    logger.setLevel(logging.INFO) 

    if logger.handlers:
        logger.handlers.clear()

    formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

    console_handler = logging.StreamHandler()
    console_handler.setLevel(logging.INFO)
    console_handler.setFormatter(formatter)
    logger.addHandler(console_handler)

    file_handler = logging.FileHandler(full_path2save, mode='a', encoding='utf-8')
    file_handler.setLevel(logging.DEBUG) 
    file_handler.setFormatter(formatter)
    logger.addHandler(file_handler)

    return logger

# %%
def save_checkpoint(state: dict, dir_name: str, filename: str) -> str:
    path2save = f"{dir_name}/{filename}"
    torch.save(state, path2save)
    return path2save

def compute_metrics(
    model: nn.Module, 
    dataloader: DataLoader, 
    device: str = "cpu"
    ):
    """Считает все важные метрики на валидационном/тестовом датасете"""
    model.eval()
    
    all_preds = []
    all_labels = []
    
    with torch.no_grad():
        for images, labels in tqdm(dataloader, desc="Computing metrics"):

            outputs = model(images.to(device))
            preds = torch.argmax(outputs, dim=1)          
            
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    
    all_preds = np.array(all_preds)
    all_labels = np.array(all_labels)
    
    metrics = {
        "accuracy": accuracy_score(all_labels, all_preds),
        "balanced_accuracy": balanced_accuracy_score(all_labels, all_preds),
        "f1": f1_score(all_labels, all_preds, average="binary", pos_label=1),   # lesion = 1
        "precision": precision_score(all_labels, all_preds, average="binary", pos_label=1),
        "recall": recall_score(all_labels, all_preds, average="binary", pos_label=1),
    }
    
    return metrics

def valid_loop(
    model: nn.Module, 
    loss_fn, 
    dataloader: DataLoader, 
    device: str = "cpu"
    ):
    """Функция с циклом валидации"""
    model.eval()
    total_loss = 0.0
    num_batchs = 0
    for batch_idx, (images, labels) in tqdm(enumerate(dataloader), desc="valid"):
        with torch.no_grad():
            out = model(images.to(device))
        loss = loss_fn(out, labels.to(device))      
        total_loss += loss.item()
        num_batchs+=1
    total_loss /= num_batchs
    return total_loss

def befor_train_init(
    dir_for_model_save: str,
    model_name: str,
    time_start: str,
    prefix_train: str
    ):
    # === create base dir for checkpoints and logs ===
    os.makedirs(dir_for_model_save, exist_ok=True)
    
    # === create dir for arch model ===
    os.makedirs(f"{dir_for_model_save}/{model_name}", exist_ok=True)

    # === create dir for current experiment ====
    dir_name = f"{time_start}_{prefix_train}"
    full_path_dir = f"{dir_for_model_save}/{model_name}/{dir_name}"
    os.makedirs(full_path_dir, exist_ok=True)

    # checkpoint dir
    os.makedirs(f"{full_path_dir}/checkpoint", exist_ok=True)
    return full_path_dir

def train_loop(
    model: nn.Module, 
    loss_fn, 
    optimizer, 
    dataloader: DataLoader, 
    valid_loader: DataLoader, 
    path_to_model_save: str,
    step_batch_log: int = 10,
    early_stopping_epoch: int = 0,
    logger = None,
    device: str = "cpu", 
    epochs: int = 1,
    scheduler = None,
    seed: int = 42
    ):

    history = {
        "totals_loss" : [],
        "valids_loss" : [],
        "balanced_accuracies" : [],
        "metrics": []
    }
    
    best_balanced_accuracy = 0.0
    early_counter = 0

    for epoch in range(epochs):
        
        model.train()
        total_loss = 0.0

        for batch_idx, (images, labels) in tqdm(enumerate(dataloader), desc="train"):
            optimizer.zero_grad(set_to_none=True) # <--- CHANGE (set_to_none=True)
            # images: torch.Size([16, 3, 224, 224])
            out = model(images.to(device))
            loss = loss_fn(out, labels.to(device))      
            total_loss += loss.item()
            loss.backward()
            optimizer.step()

            if (batch_idx+1)%step_batch_log==0:
                if logger:
                    num_exmpls = images.shape[0] * (batch_idx+1)
                    logger.info(f"epoch {epoch+1} | batch {batch_idx+1} | train_loss: {(total_loss/num_exmpls):.8f}")

        # ===========================================================================

        total_loss /= len(dataloader)
        
        # === valid ===
        valid_loss = valid_loop(model, loss_fn, valid_loader, device=device)
        
        # === metrics calculate ===
        metrics = compute_metrics(model, valid_loader, device)
        curr_balanced_accuracy = metrics.get("balanced_accuracy", 0.0)
        
        # === save for log ===
        history['totals_loss'].append(total_loss)
        history['valids_loss'].append(valid_loss)

        for key in list(metrics.keys()):
            if key not in history:
                history[key] = []
            history[key].append(metrics[key])


        # === scheduler run ===
        if scheduler:
            scheduler.step(curr_balanced_accuracy)

        # === logging ===
        if logger:
            logger.info(f"================= epoch end =================")
            logger.info(f"epoch {epoch+1} | train_loss: {total_loss:.8f} | valid_loss: {valid_loss:.8f} | valid balanc. acc.: {curr_balanced_accuracy:.8f}")
            # log metrics
            logger.info(f"metrics:\n{metrics}")

        # === save best model ===
        if curr_balanced_accuracy > best_balanced_accuracy:
            best_balanced_accuracy = curr_balanced_accuracy
            early_counter = 0
            state = {
                "epoch": epoch,
                "state_dict": model.state_dict(),
                "optimizer": optimizer.state_dict(),
                "best_blns_acc": best_balanced_accuracy,
                "seed": seed
            }
            path2save = save_checkpoint(state, f"{path_to_model_save}/checkpoint", "best_model.pth")
            if logger:
                logger.info(f"save checkpoint: {path2save}")
        else:
            early_counter += 1

        # === create early stopping ===
        if (early_stopping_epoch != 0) and (early_counter >= early_stopping_epoch):
            if logger:
                logger.info(f"Early stopping. Epoch: {epoch+1}")
                logger.info(f"best balanced accuracy: {best_balanced_accuracy}")
            break
        
    return history

# %%
time_now = dt.datetime.now().strftime("%Y-%m-%d_%H_%M_%S")
path2save = befor_train_init(
    path2model_save,
    model_name,
    time_now,
    prefix_train
)
train_logger = create_logger(path2save, "train_log.log")
train_logger.info(comment)
# Out:
# 2026-04-23 18:17:44,577 - INFO -
# ===== general parameters =====
# SEED: 42
# DEVICE: cuda
#
# BATCH_SIZE: 16
# input_img_shape: (3, 224, 224)
# split_level: video_id
#
# ===== train parameters =====
#
# LR: 0.0001
#
#
# CV_N: 5
# EPOCHS: 10
# STEP_BATCH_LOG: 10
#
# ===== about model and save =====
# base_dir_for_model_save: ..\models_checkpoints
#
# model_name: resnet_18_backbone_cv
# prefix_train: full_tuning_patient
#
# ===== comments =====
# LCA
# cross-validation
# split patient level
# SGDM optimizer
# use augmentation
# use ImageNet stats for (mean, std) normalization

# %%
transform_images = v2.Compose([
    v2.ToTensor(),
    v2.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])
# Out:
# c:\dev\mlRes\mlenv\lib\site-packages\torchvision\transforms\v2\_deprecated.py:42: UserWarning: The transform `ToTensor()` is deprecated and will be removed in a future release. Instead, please use `v2.Compose([v2.ToImage(), v2.ToDtype(torch.float32, scale=True)])`.Output is equivalent up to float precision.
#   warnings.warn(

# %% [markdown]
# ### CV

# %%
# Группировка по видео (все фреймы одного видео идут в одну часть)
groups = df_train['video_id'].values
sgkf = StratifiedGroupKFold(n_splits=CV_N, shuffle=True, random_state=SEED)


for fold, (train_idx, val_idx) in enumerate(sgkf.split(df_train, df_train['label'], groups)):
    train_logger.info(f"Fold {fold + 1}")

    # === for dataset for train and val ===
    df_train_folds = df_train.iloc[train_idx].reset_index(drop=True)
    df_val_fold = df_train.iloc[val_idx].reset_index(drop=True)
    
    train_logger.info(f'''
    ======= about folds =======
    {df_train_folds.shape, df_val_fold.shape}
    {set(df_train_folds['video_id'].unique()).intersection(df_val_fold['video_id'].unique())}
    {df_train_folds.groupby("label")['image_path'].count()}     
    {df_val_fold.groupby("label")['image_path'].count()}
    ''')

    # === create dataset objects ===
    df_train_folds = CADICADataset(df_train_folds, "image_path", "label", transform=transform_images)
    df_val_fold = CADICADataset(df_val_fold, "image_path", "label", transform=transform_images)

    # === create loaders ===
    train_loader = DataLoader(df_train_folds, batch_size=BATCH_SIZE, shuffle=True, num_workers=0)
    val_loader = DataLoader(df_val_fold, batch_size=BATCH_SIZE, shuffle=True, num_workers=0)

    # === init model ===
    model = ResNet_18_Backbone(img_size=input_img_shape, out_classes=2, freeze_backbone=False).to(DEVICE)
    optimizer = optim.RMSprop(model.parameters(), lr=LR)
    loss_fn = nn.CrossEntropyLoss()

    total_params = sum(p.numel() for p in model.parameters())
    trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    train_logger.info(f'''
    Всего параметров: {total_params:,}
    Обучаемых:       {trainable_params:,}
    ''')

    # ========== create dir for save model ==========
    path2save_model_fold = f"{path2save}/fold{fold+1}"
    os.makedirs(path2save_model_fold, exist_ok=True)
    os.makedirs(f"{path2save_model_fold}/checkpoint", exist_ok=True)

    # ========== Запуск цикла обучения ==========
    train_history = train_loop(
        model, 
        loss_fn, 
        optimizer, 
        train_loader, 
        val_loader, 
        path_to_model_save=path2save_model_fold,
        step_batch_log = STEP_BATCH_LOG,
        early_stopping_epoch = 0,
        logger = train_logger,
        device = DEVICE, 
        epochs = EPOCHS,
        seed = SEED
    )

    # ========== Сохранение метрик хода обучения ==========
    with open(f"{path2save_model_fold}/train_history.json", "w", encoding="utf-8") as f:
        json.dump(train_history, f, ensure_ascii=False, indent=4)
# Out:
# 2026-04-23 18:17:46,444 - INFO - Fold 1
# 2026-04-23 18:17:46,473 - INFO -
#     ======= about folds =======
#     ((5601, 8), (1679, 8))
#     set()
#     label
# 0    2619
# 1    2982
# Name: image_path, dtype: int64
#     label
# 0    1021
# 1     658
# Name: image_path, dtype: int64
#
# 2026-04-23 18:17:47,405 - INFO -
#     Всего параметров: 11,177,538
#     Обучаемых:       11,177,538
#
# train: 9it [00:03,  4.28it/s]2026-04-23 18:17:50,792 - INFO - epoch 1 | batch 10 | train_loss: 0.05596096
# train: 19it [00:05,  4.71it/s]2026-04-23 18:17:52,802 - INFO - epoch 1 | batch 20 | train_loss: 0.04783927
# train: 29it [00:07,  4.88it/s]2026-04-23 18:17:54,806 - INFO - epoch 1 | batch 30 | train_loss: 0.04296825
# train: 39it [00:09,  4.73it/s]2026-04-23 18:17:56,836 - INFO - epoch 1 | batch 40 | train_loss: 0.03839317
# train: 49it [00:11,  5.40it/s]2026-04-23 18:17:58,706 - INFO - epoch 1 | batch 50 | train_loss: 0.03687996
# train: 59it [00:12,  5.74it/s]2026-04-23 18:18:00,412 - INFO - epoch 1 | batch 60 | train_loss: 0.03374212
# train: 69it [00:14,  4.86it/s]2026-04-23 18:18:02,438 - INFO - epoch 1 | batch 70 | train_loss: 0.03175075
# train: 79it [00:16,  4.69it/s]2026-04-23 18:18:04,606 - INFO - epoch 1 | batch 80 | train_loss: 0.03017354
# train: 89it [00:19,  4.94it/s]2026-04-23 18:18:06,636 - INFO - epoch 1 | batch 90 | train_loss: 0.02899897
# train: 99it [00:20,  5.21it/s]2026-04-23 18:18:08,548 - INFO - epoch 1 | batch 100 | train_loss: 0.02794673
# train: 109it [00:22,  6.00it/s]2026-04-23 18:18:10,220 - INFO - epoch 1 | batch 110 | train_loss: 0.02702486
# train: 119it [00:24,  5.32it/s]2026-04-23 18:18:12,103 - INFO - epoch 1 | batch 120 | train_loss: 0.02584891
# train: 129it [00:26,  4.19it/s]2026-04-23 18:18:14,438 - INFO - epoch 1 | batch 130 | train_loss: 0.02499922
# train: 139it [00:28,  5.25it/s]2026-04-23 18:18:16,384 - INFO - epoch 1 | batch 140 | train_loss: 0.02404297
# train: 149it [00:30,  4.75it/s]2026-04-23 18:18:18,292 - INFO - epoch 1 | batch 150 | train_loss: 0.02285489
# train: 159it [00:32,  5.80it/s]2026-04-23 18:18:20,002 - INFO - epoch 1 | batch 160 | train_loss: 0.02230760
# train: 169it [00:34,  5.71it/s]2026-04-23 18:18:21,710 - INFO - epoch 1 | batch 170 | train_loss: 0.02167125
# train: 179it [00:35,  5.67it/s]2026-04-23 18:18:23,442 - INFO - epoch 1 | batch 180 | train_loss: 0.02081620
# train: 189it [00:37,  5.82it/s]2026-04-23 18:18:25,162 - INFO - epoch 1 | batch 190 | train_loss: 0.02035161
# train: 199it [00:39,  5.87it/s]2026-04-23 18:18:26,887 - INFO - epoch 1 | batch 200 | train_loss: 0.01973119
# train: 209it [00:41,  5.78it/s]2026-04-23 18:18:28,592 - INFO - epoch 1 | batch 210 | train_loss: 0.01950215
# train: 219it [00:42,  5.88it/s]2026-04-23 18:18:30,312 - INFO - epoch 1 | batch 220 | train_loss: 0.01912939
# train: 229it [00:44,  6.11it/s]2026-04-23 18:18:31,948 - INFO - epoch 1 | batch 230 | train_loss: 0.01854929
# train: 239it [00:46,  5.89it/s]2026-04-23 18:18:33,637 - INFO - epoch 1 | batch 240 | train_loss: 0.01819626
# train: 249it [00:47,  5.83it/s]2026-04-23 18:18:35,346 - INFO - epoch 1 | batch 250 | train_loss: 0.01781796
# train: 259it [00:49,  6.19it/s]2026-04-23 18:18:36,972 - INFO - epoch 1 | batch 260 | train_loss: 0.01729512
# train: 269it [00:51,  6.14it/s]2026-04-23 18:18:38,592 - INFO - epoch 1 | batch 270 | train_loss: 0.01686464
# train: 279it [00:52,  5.46it/s]2026-04-23 18:18:40,302 - INFO - epoch 1 | batch 280 | train_loss: 0.01665487
# train: 289it [00:54,  6.06it/s]2026-04-23 18:18:41,947 - INFO - epoch 1 | batch 290 | train_loss: 0.01629489
# train: 299it [00:56,  5.27it/s]2026-04-23 18:18:43,785 - INFO - epoch 1 | batch 300 | train_loss: 0.01608527
# train: 309it [00:57,  5.60it/s]2026-04-23 18:18:45,525 - INFO - epoch 1 | batch 310 | train_loss: 0.01586566
# train: 319it [00:59,  5.32it/s]2026-04-23 18:18:47,390 - INFO - epoch 1 | batch 320 | train_loss: 0.01550795
# train: 329it [01:01,  5.59it/s]2026-04-23 18:18:49,212 - INFO - epoch 1 | batch 330 | train_loss: 0.01514786
# train: 339it [01:03,  5.72it/s]2026-04-23 18:18:50,976 - INFO - epoch 1 | batch 340 | train_loss: 0.01483676
# train: 349it [01:05,  5.56it/s]2026-04-23 18:18:52,775 - INFO - epoch 1 | batch 350 | train_loss: 0.01465010
# train: 351it [01:05,  5.35it/s]
# valid: 105it [00:21,  4.92it/s]
# Computing metrics: 100%|██████████| 105/105 [00:06<00:00, 16.90it/s]
# 2026-04-23 18:19:20,574 - INFO - ================= epoch end =================
# 2026-04-23 18:19:20,576 - INFO - epoch 1 | train_loss: 0.23486306 | valid_loss: 1.76044167 | valid balanc. acc.: 0.61762040
# 2026-04-23 18:19:20,578 - INFO - metrics:
# {'accuracy': 0.5878499106611078, 'balanced_accuracy': 0.6176203971909059, 'f1': 0.5895610913404508, 'precision': 0.48346303501945526, 'recall': 0.7553191489361702}
# 2026-04-23 18:19:20,698 - INFO - save checkpoint: ..\models_checkpoints/resnet_18_backbone_cv/2026-04-23_18_17_44_full_tuning_patient/fold1/checkpoint/best_model.pth
# train: 8it [00:00, 12.47it/s]2026-04-23 18:19:21,509 - INFO - epoch 2 | batch 10 | train_loss: 0.00272490
# train: 18it [00:01, 12.30it/s]2026-04-23 18:19:22,319 - INFO - epoch 2 | batch 20 | train_loss: 0.00471286
# train: 28it [00:02, 12.30it/s]2026-04-23 18:19:23,132 - INFO - epoch 2 | batch 30 | train_loss: 0.00395682
# train: 38it [00:03, 12.28it/s]2026-04-23 18:19:23,944 - INFO - epoch 2 | batch 40 | train_loss: 0.00347260
# train: 48it [00:03, 12.27it/s]2026-04-23 18:19:24,755 - INFO - epoch 2 | batch 50 | train_loss: 0.00313493
# train: 58it [00:04, 11.28it/s]2026-04-23 18:19:25,671 - INFO - epoch 2 | batch 60 | train_loss: 0.00293169
# train: 68it [00:05, 12.09it/s]2026-04-23 18:19:26,482 - INFO - epoch 2 | batch 70 | train_loss: 0.00257895
# train: 78it [00:06, 12.27it/s]2026-04-23 18:19:27,287 - INFO - epoch 2 | batch 80 | train_loss: 0.00255908
# train: 88it [00:07, 12.49it/s]2026-04-23 18:19:28,099 - INFO - epoch 2 | batch 90 | train_loss: 0.00236300
# train: 98it [00:08, 12.33it/s]2026-04-23 18:19:28,903 - INFO - epoch 2 | batch 100 | train_loss: 0.00230937
# train: 108it [00:08, 12.40it/s]2026-04-23 18:19:29,712 - INFO - epoch 2 | batch 110 | train_loss: 0.00250496
# train: 118it [00:09, 12.41it/s]2026-04-23 18:19:30,515 - INFO - epoch 2 | batch 120 | train_loss: 0.00275931
# train: 128it [00:10, 12.37it/s]2026-04-23 18:19:31,344 - INFO - epoch 2 | batch 130 | train_loss: 0.00340856
# train: 138it [00:11, 12.29it/s]2026-04-23 18:19:32,149 - INFO - epoch 2 | batch 140 | train_loss: 0.00344234
# train: 148it [00:12, 12.25it/s]2026-04-23 18:19:32,962 - INFO - epoch 2 | batch 150 | train_loss: 0.00333032
# train: 158it [00:12, 12.40it/s]2026-04-23 18:19:33,768 - INFO - epoch 2 | batch 160 | train_loss: 0.00336549
# train: 168it [00:13, 12.44it/s]2026-04-23 18:19:34,576 - INFO - epoch 2 | batch 170 | train_loss: 0.00324505
# train: 178it [00:14, 12.33it/s]2026-04-23 18:19:35,382 - INFO - epoch 2 | batch 180 | train_loss: 0.00346104
# train: 188it [00:15, 12.42it/s]2026-04-23 18:19:36,186 - INFO - epoch 2 | batch 190 | train_loss: 0.00350847
# train: 198it [00:16, 12.40it/s]2026-04-23 18:19:36,987 - INFO - epoch 2 | batch 200 | train_loss: 0.00340538
# train: 208it [00:16, 12.27it/s]2026-04-23 18:19:37,809 - INFO - epoch 2 | batch 210 | train_loss: 0.00359138
# train: 218it [00:17, 12.27it/s]2026-04-23 18:19:38,627 - INFO - epoch 2 | batch 220 | train_loss: 0.00375251
# train: 228it [00:18, 12.29it/s]2026-04-23 18:19:39,434 - INFO - epoch 2 | batch 230 | train_loss: 0.00368519
# train: 238it [00:19, 12.54it/s]2026-04-23 18:19:40,242 - INFO - epoch 2 | batch 240 | train_loss: 0.00405992
# train: 248it [00:20, 12.40it/s]2026-04-23 18:19:41,047 - INFO - epoch 2 | batch 250 | train_loss: 0.00414347
# train: 258it [00:20, 12.45it/s]2026-04-23 18:19:41,851 - INFO - epoch 2 | batch 260 | train_loss: 0.00409440
# train: 268it [00:21, 12.42it/s]2026-04-23 18:19:42,656 - INFO - epoch 2 | batch 270 | train_loss: 0.00402078
# train: 278it [00:22, 12.27it/s]2026-04-23 18:19:43,463 - INFO - epoch 2 | batch 280 | train_loss: 0.00393529
# train: 288it [00:23, 12.29it/s]2026-04-23 18:19:44,273 - INFO - epoch 2 | batch 290 | train_loss: 0.00387767
# train: 298it [00:24, 12.36it/s]2026-04-23 18:19:45,082 - INFO - epoch 2 | batch 300 | train_loss: 0.00391177
# train: 308it [00:25, 12.38it/s]2026-04-23 18:19:45,892 - INFO - epoch 2 | batch 310 | train_loss: 0.00400275
# train: 318it [00:25, 12.30it/s]2026-04-23 18:19:46,702 - INFO - epoch 2 | batch 320 | train_loss: 0.00400068
# train: 328it [00:26, 12.48it/s]2026-04-23 18:19:47,507 - INFO - epoch 2 | batch 330 | train_loss: 0.00393352
# train: 338it [00:27, 12.40it/s]2026-04-23 18:19:48,312 - INFO - epoch 2 | batch 340 | train_loss: 0.00387328
# train: 348it [00:28, 12.44it/s]2026-04-23 18:19:49,114 - INFO - epoch 2 | batch 350 | train_loss: 0.00380612
# train: 351it [00:28, 12.33it/s]
# valid: 105it [00:05, 18.06it/s]
# Computing metrics: 100%|██████████| 105/105 [00:05<00:00, 18.07it/s]
# 2026-04-23 18:20:00,803 - INFO - ================= epoch end =================
# 2026-04-23 18:20:00,812 - INFO - epoch 2 | train_loss: 0.06120349 | valid_loss: 2.62198521 | valid balanc. acc.: 0.58430185
# 2026-04-23 18:20:00,812 - INFO - metrics:
# {'accuracy': 0.5348421679571174, 'balanced_accuracy': 0.5843018496080783, 'f1': 0.5780659103187467, 'precision': 0.4484492875104778, 'recall': 0.8130699088145896}
# train: 8it [00:00, 12.58it/s]2026-04-23 18:20:01,602 - INFO - epoch 3 | batch 10 | train_loss: 0.00337820
# train: 18it [00:01, 12.53it/s]2026-04-23 18:20:02,404 - INFO - epoch 3 | batch 20 | train_loss: 0.00453769
# train: 28it [00:02, 12.44it/s]2026-04-23 18:20:03,202 - INFO - epoch 3 | batch 30 | train_loss: 0.00334158
# train: 38it [00:03, 12.52it/s]2026-04-23 18:20:04,010 - INFO - epoch 3 | batch 40 | train_loss: 0.00305489
# train: 48it [00:03, 12.40it/s]2026-04-23 18:20:04,812 - INFO - epoch 3 | batch 50 | train_loss: 0.00300209
# train: 58it [00:04, 12.13it/s]2026-04-23 18:20:05,625 - INFO - epoch 3 | batch 60 | train_loss: 0.00261413
# train: 68it [00:05, 12.56it/s]2026-04-23 18:20:06,432 - INFO - epoch 3 | batch 70 | train_loss: 0.00235101
# train: 78it [00:06, 12.36it/s]2026-04-23 18:20:07,236 - INFO - epoch 3 | batch 80 | train_loss: 0.00223974
# train: 88it [00:07, 12.40it/s]2026-04-23 18:20:08,039 - INFO - epoch 3 | batch 90 | train_loss: 0.00213071
# train: 98it [00:07, 12.59it/s]2026-04-23 18:20:08,841 - INFO - epoch 3 | batch 100 | train_loss: 0.00201148
# train: 108it [00:08, 12.42it/s]2026-04-23 18:20:09,644 - INFO - epoch 3 | batch 110 | train_loss: 0.00193005
# train: 118it [00:09, 12.42it/s]2026-04-23 18:20:10,442 - INFO - epoch 3 | batch 120 | train_loss: 0.00181165
# train: 128it [00:10, 12.44it/s]2026-04-23 18:20:11,250 - INFO - epoch 3 | batch 130 | train_loss: 0.00182883
# train: 138it [00:11, 12.45it/s]2026-04-23 18:20:12,050 - INFO - epoch 3 | batch 140 | train_loss: 0.00245675
# train: 148it [00:11, 12.47it/s]2026-04-23 18:20:12,852 - INFO - epoch 3 | batch 150 | train_loss: 0.00267638
# train: 158it [00:12, 12.46it/s]2026-04-23 18:20:13,654 - INFO - epoch 3 | batch 160 | train_loss: 0.00309449
# train: 168it [00:13, 12.37it/s]2026-04-23 18:20:14,456 - INFO - epoch 3 | batch 170 | train_loss: 0.00314895
# train: 178it [00:14, 12.44it/s]2026-04-23 18:20:15,262 - INFO - epoch 3 | batch 180 | train_loss: 0.00308995
# train: 188it [00:15, 12.48it/s]2026-04-23 18:20:16,062 - INFO - epoch 3 | batch 190 | train_loss: 0.00314043
# train: 198it [00:15, 12.41it/s]2026-04-23 18:20:16,866 - INFO - epoch 3 | batch 200 | train_loss: 0.00325074
# train: 208it [00:16, 12.42it/s]2026-04-23 18:20:17,666 - INFO - epoch 3 | batch 210 | train_loss: 0.00322771
# train: 218it [00:17, 12.37it/s]2026-04-23 18:20:18,472 - INFO - epoch 3 | batch 220 | train_loss: 0.00316506
# train: 228it [00:18, 12.48it/s]2026-04-23 18:20:19,278 - INFO - epoch 3 | batch 230 | train_loss: 0.00340445
# train: 238it [00:19, 12.43it/s]2026-04-23 18:20:20,074 - INFO - epoch 3 | batch 240 | train_loss: 0.00345047
# train: 248it [00:19, 11.92it/s]2026-04-23 18:20:20,923 - INFO - epoch 3 | batch 250 | train_loss: 0.00341628
# train: 258it [00:20, 12.29it/s]2026-04-23 18:20:21,733 - INFO - epoch 3 | batch 260 | train_loss: 0.00335578
# train: 268it [00:21, 12.51it/s]2026-04-23 18:20:22,539 - INFO - epoch 3 | batch 270 | train_loss: 0.00333525
# train: 278it [00:22, 12.40it/s]2026-04-23 18:20:23,344 - INFO - epoch 3 | batch 280 | train_loss: 0.00325245
# train: 288it [00:23, 12.44it/s]2026-04-23 18:20:24,142 - INFO - epoch 3 | batch 290 | train_loss: 0.00319120
# train: 298it [00:23, 12.45it/s]2026-04-23 18:20:24,950 - INFO - epoch 3 | batch 300 | train_loss: 0.00318725
# train: 308it [00:24, 12.45it/s]2026-04-23 18:20:25,753 - INFO - epoch 3 | batch 310 | train_loss: 0.00315237
# train: 318it [00:25, 12.53it/s]2026-04-23 18:20:26,556 - INFO - epoch 3 | batch 320 | train_loss: 0.00306546
# train: 328it [00:26, 12.41it/s]2026-04-23 18:20:27,362 - INFO - epoch 3 | batch 330 | train_loss: 0.00300538
# train: 338it [00:27, 12.47it/s]2026-04-23 18:20:28,163 - INFO - epoch 3 | batch 340 | train_loss: 0.00321127
# train: 348it [00:27, 12.41it/s]2026-04-23 18:20:28,968 - INFO - epoch 3 | batch 350 | train_loss: 0.00316957
# train: 351it [00:28, 12.44it/s]
# valid: 105it [00:06, 17.18it/s]
# Computing metrics: 100%|██████████| 105/105 [00:05<00:00, 17.72it/s]
# 2026-04-23 18:20:41,090 - INFO - ================= epoch end =================
# 2026-04-23 18:20:41,091 - INFO - epoch 3 | train_loss: 0.05109391 | valid_loss: 2.57850239 | valid balanc. acc.: 0.54450089
# 2026-04-23 18:20:41,092 - INFO - metrics:
# {'accuracy': 0.5008933889219773, 'balanced_accuracy': 0.5445008916105255, 'f1': 0.5395604395604395, 'precision': 0.4225473321858864, 'recall': 0.7462006079027356}
# train: 8it [00:00, 12.38it/s]2026-04-23 18:20:41,900 - INFO - epoch 4 | batch 10 | train_loss: 0.00093512
# train: 18it [00:01, 12.41it/s]2026-04-23 18:20:42,715 - INFO - epoch 4 | batch 20 | train_loss: 0.00088637
# train: 28it [00:02, 12.26it/s]2026-04-23 18:20:43,545 - INFO - epoch 4 | batch 30 | train_loss: 0.00191885
# train: 38it [00:03, 12.41it/s]2026-04-23 18:20:44,354 - INFO - epoch 4 | batch 40 | train_loss: 0.00188868
# train: 48it [00:03, 12.50it/s]2026-04-23 18:20:45,162 - INFO - epoch 4 | batch 50 | train_loss: 0.00178744
# train: 58it [00:04, 12.35it/s]2026-04-23 18:20:45,964 - INFO - epoch 4 | batch 60 | train_loss: 0.00217689
# train: 68it [00:05, 12.34it/s]2026-04-23 18:20:46,779 - INFO - epoch 4 | batch 70 | train_loss: 0.00199474
# train: 78it [00:06, 12.32it/s]2026-04-23 18:20:47,582 - INFO - epoch 4 | batch 80 | train_loss: 0.00181349
# train: 88it [00:07, 12.38it/s]2026-04-23 18:20:48,382 - INFO - epoch 4 | batch 90 | train_loss: 0.00188952
# train: 98it [00:07, 12.33it/s]2026-04-23 18:20:49,193 - INFO - epoch 4 | batch 100 | train_loss: 0.00192671
# train: 108it [00:08, 12.51it/s]2026-04-23 18:20:49,997 - INFO - epoch 4 | batch 110 | train_loss: 0.00177576
# train: 118it [00:09, 12.38it/s]2026-04-23 18:20:50,802 - INFO - epoch 4 | batch 120 | train_loss: 0.00170453
# train: 128it [00:10, 12.46it/s]2026-04-23 18:20:51,611 - INFO - epoch 4 | batch 130 | train_loss: 0.00167098
# train: 138it [00:11, 12.44it/s]2026-04-23 18:20:52,420 - INFO - epoch 4 | batch 140 | train_loss: 0.00160477
# train: 148it [00:11, 12.42it/s]2026-04-23 18:20:53,224 - INFO - epoch 4 | batch 150 | train_loss: 0.00153082
# train: 158it [00:12, 12.33it/s]2026-04-23 18:20:54,031 - INFO - epoch 4 | batch 160 | train_loss: 0.00152235
# train: 168it [00:13, 12.46it/s]2026-04-23 18:20:54,837 - INFO - epoch 4 | batch 170 | train_loss: 0.00148376
# train: 178it [00:14, 11.67it/s]2026-04-23 18:20:55,691 - INFO - epoch 4 | batch 180 | train_loss: 0.00147360
# train: 188it [00:15, 12.26it/s]2026-04-23 18:20:56,498 - INFO - epoch 4 | batch 190 | train_loss: 0.00160921
# train: 198it [00:16, 11.28it/s]2026-04-23 18:20:57,378 - INFO - epoch 4 | batch 200 | train_loss: 0.00182978
# train: 208it [00:16, 12.03it/s]2026-04-23 18:20:58,192 - INFO - epoch 4 | batch 210 | train_loss: 0.00176980
# train: 218it [00:17, 11.86it/s]2026-04-23 18:20:59,030 - INFO - epoch 4 | batch 220 | train_loss: 0.00174761
# train: 228it [00:18, 12.30it/s]2026-04-23 18:20:59,835 - INFO - epoch 4 | batch 230 | train_loss: 0.00168769
# train: 238it [00:19, 12.33it/s]2026-04-23 18:21:00,643 - INFO - epoch 4 | batch 240 | train_loss: 0.00172312
# train: 248it [00:20, 12.40it/s]2026-04-23 18:21:01,450 - INFO - epoch 4 | batch 250 | train_loss: 0.00177129
# train: 258it [00:21, 12.36it/s]2026-04-23 18:21:02,258 - INFO - epoch 4 | batch 260 | train_loss: 0.00172288
# train: 268it [00:21, 12.37it/s]2026-04-23 18:21:03,068 - INFO - epoch 4 | batch 270 | train_loss: 0.00167462
# train: 278it [00:22, 12.38it/s]2026-04-23 18:21:03,874 - INFO - epoch 4 | batch 280 | train_loss: 0.00165873
# train: 288it [00:23, 12.42it/s]2026-04-23 18:21:04,680 - INFO - epoch 4 | batch 290 | train_loss: 0.00169131
# train: 298it [00:24, 12.37it/s]2026-04-23 18:21:05,487 - INFO - epoch 4 | batch 300 | train_loss: 0.00170261
# train: 308it [00:25, 12.39it/s]2026-04-23 18:21:06,296 - INFO - epoch 4 | batch 310 | train_loss: 0.00169066
# train: 318it [00:25, 12.42it/s]2026-04-23 18:21:07,103 - INFO - epoch 4 | batch 320 | train_loss: 0.00166285
# train: 328it [00:26, 12.40it/s]2026-04-23 18:21:07,911 - INFO - epoch 4 | batch 330 | train_loss: 0.00163628
# train: 338it [00:27, 12.36it/s]2026-04-23 18:21:08,717 - INFO - epoch 4 | batch 340 | train_loss: 0.00159045
# train: 348it [00:28, 12.41it/s]2026-04-23 18:21:09,523 - INFO - epoch 4 | batch 350 | train_loss: 0.00155457
# train: 351it [00:28, 12.32it/s]
# valid: 105it [00:06, 15.91it/s]
# Computing metrics: 100%|██████████| 105/105 [00:06<00:00, 15.78it/s]
# 2026-04-23 18:21:22,856 - INFO - ================= epoch end =================
# 2026-04-23 18:21:22,857 - INFO - epoch 4 | train_loss: 0.03109924 | valid_loss: 3.21564574 | valid balanc. acc.: 0.56749894
# 2026-04-23 18:21:22,858 - INFO - metrics:
# {'accuracy': 0.5068493150684932, 'balanced_accuracy': 0.5674989357236633, 'f1': 0.5740740740740741, 'precision': 0.43390357698289267, 'recall': 0.8480243161094225}
# train: 8it [00:00, 12.36it/s]2026-04-23 18:21:23,667 - INFO - epoch 5 | batch 10 | train_loss: 0.00079218
# train: 18it [00:01, 12.33it/s]2026-04-23 18:21:24,477 - INFO - epoch 5 | batch 20 | train_loss: 0.00071823
# train: 28it [00:02, 12.36it/s]2026-04-23 18:21:25,288 - INFO - epoch 5 | batch 30 | train_loss: 0.00053896
# train: 38it [00:03, 12.24it/s]2026-04-23 18:21:26,104 - INFO - epoch 5 | batch 40 | train_loss: 0.00048078
# train: 48it [00:03, 12.16it/s]2026-04-23 18:21:26,934 - INFO - epoch 5 | batch 50 | train_loss: 0.00088845
# train: 58it [00:04, 12.38it/s]2026-04-23 18:21:27,739 - INFO - epoch 5 | batch 60 | train_loss: 0.00109550
# train: 68it [00:05, 12.41it/s]2026-04-23 18:21:28,545 - INFO - epoch 5 | batch 70 | train_loss: 0.00103342
# train: 78it [00:06, 12.37it/s]2026-04-23 18:21:29,351 - INFO - epoch 5 | batch 80 | train_loss: 0.00109220
# train: 88it [00:07, 12.39it/s]2026-04-23 18:21:30,159 - INFO - epoch 5 | batch 90 | train_loss: 0.00160503
# train: 98it [00:07, 12.33it/s]2026-04-23 18:21:30,969 - INFO - epoch 5 | batch 100 | train_loss: 0.00238222
# train: 108it [00:08, 12.39it/s]2026-04-23 18:21:31,777 - INFO - epoch 5 | batch 110 | train_loss: 0.00223525
# train: 118it [00:09, 12.16it/s]2026-04-23 18:21:32,618 - INFO - epoch 5 | batch 120 | train_loss: 0.00248658
# train: 128it [00:10, 12.40it/s]2026-04-23 18:21:33,424 - INFO - epoch 5 | batch 130 | train_loss: 0.00240971
# train: 138it [00:11, 12.30it/s]2026-04-23 18:21:34,243 - INFO - epoch 5 | batch 140 | train_loss: 0.00242934
# train: 148it [00:12, 12.38it/s]2026-04-23 18:21:35,052 - INFO - epoch 5 | batch 150 | train_loss: 0.00231016
# train: 158it [00:12, 12.38it/s]2026-04-23 18:21:35,858 - INFO - epoch 5 | batch 160 | train_loss: 0.00220914
# train: 168it [00:13, 12.42it/s]2026-04-23 18:21:36,665 - INFO - epoch 5 | batch 170 | train_loss: 0.00214184
# train: 178it [00:14, 12.40it/s]2026-04-23 18:21:37,472 - INFO - epoch 5 | batch 180 | train_loss: 0.00204219
# train: 188it [00:15, 12.22it/s]2026-04-23 18:21:38,300 - INFO - epoch 5 | batch 190 | train_loss: 0.00194171
# train: 198it [00:16, 12.34it/s]2026-04-23 18:21:39,110 - INFO - epoch 5 | batch 200 | train_loss: 0.00187493
# train: 208it [00:16, 11.48it/s]2026-04-23 18:21:40,005 - INFO - epoch 5 | batch 210 | train_loss: 0.00181959
# train: 218it [00:17, 11.78it/s]2026-04-23 18:21:40,841 - INFO - epoch 5 | batch 220 | train_loss: 0.00191139
# train: 228it [00:18, 12.23it/s]2026-04-23 18:21:41,649 - INFO - epoch 5 | batch 230 | train_loss: 0.00201026
# train: 238it [00:19, 12.45it/s]2026-04-23 18:21:42,454 - INFO - epoch 5 | batch 240 | train_loss: 0.00206961
# train: 248it [00:20, 11.45it/s]2026-04-23 18:21:43,306 - INFO - epoch 5 | batch 250 | train_loss: 0.00200764
# train: 258it [00:21, 11.97it/s]2026-04-23 18:21:44,136 - INFO - epoch 5 | batch 260 | train_loss: 0.00202675
# train: 268it [00:21, 11.67it/s]2026-04-23 18:21:44,982 - INFO - epoch 5 | batch 270 | train_loss: 0.00229797
# train: 278it [00:22, 12.20it/s]2026-04-23 18:21:45,787 - INFO - epoch 5 | batch 280 | train_loss: 0.00229660
# train: 288it [00:23, 12.48it/s]2026-04-23 18:21:46,597 - INFO - epoch 5 | batch 290 | train_loss: 0.00232673
# train: 298it [00:24, 12.36it/s]2026-04-23 18:21:47,406 - INFO - epoch 5 | batch 300 | train_loss: 0.00230389
# train: 308it [00:25, 12.36it/s]2026-04-23 18:21:48,210 - INFO - epoch 5 | batch 310 | train_loss: 0.00225449
# train: 318it [00:25, 12.43it/s]2026-04-23 18:21:49,017 - INFO - epoch 5 | batch 320 | train_loss: 0.00222406
# train: 328it [00:26, 12.35it/s]2026-04-23 18:21:49,824 - INFO - epoch 5 | batch 330 | train_loss: 0.00219658
# train: 338it [00:27, 12.46it/s]2026-04-23 18:21:50,627 - INFO - epoch 5 | batch 340 | train_loss: 0.00215054
# train: 348it [00:28, 12.38it/s]2026-04-23 18:21:51,445 - INFO - epoch 5 | batch 350 | train_loss: 0.00216312
# train: 351it [00:28, 12.25it/s]
# valid: 105it [00:06, 16.96it/s]
# Computing metrics: 100%|██████████| 105/105 [00:06<00:00, 16.92it/s]
# 2026-04-23 18:22:03,916 - INFO - ================= epoch end =================
# 2026-04-23 18:22:03,916 - INFO - epoch 5 | train_loss: 0.03871000 | valid_loss: 3.68323637 | valid balanc. acc.: 0.55250455
# 2026-04-23 18:22:03,917 - INFO - metrics:
# {'accuracy': 0.5020845741512805, 'balanced_accuracy': 0.5525045473625297, 'f1': 0.5529411764705883, 'precision': 0.4265676567656766, 'recall': 0.7857142857142857}
# train: 8it [00:00, 12.45it/s]2026-04-23 18:22:04,713 - INFO - epoch 6 | batch 10 | train_loss: 0.00051689
# train: 18it [00:01, 12.35it/s]2026-04-23 18:22:05,524 - INFO - epoch 6 | batch 20 | train_loss: 0.00036263
# train: 28it [00:02, 12.47it/s]2026-04-23 18:22:06,333 - INFO - epoch 6 | batch 30 | train_loss: 0.00032555
# train: 38it [00:03, 11.44it/s]2026-04-23 18:22:07,187 - INFO - epoch 6 | batch 40 | train_loss: 0.00036358
# train: 48it [00:03, 12.22it/s]2026-04-23 18:22:07,994 - INFO - epoch 6 | batch 50 | train_loss: 0.00039643
# train: 58it [00:04, 12.18it/s]2026-04-23 18:22:08,812 - INFO - epoch 6 | batch 60 | train_loss: 0.00035606
# train: 68it [00:05, 12.34it/s]2026-04-23 18:22:09,616 - INFO - epoch 6 | batch 70 | train_loss: 0.00036955
# train: 78it [00:06, 12.40it/s]2026-04-23 18:22:10,428 - INFO - epoch 6 | batch 80 | train_loss: 0.00035474
# train: 88it [00:07, 12.46it/s]2026-04-23 18:22:11,230 - INFO - epoch 6 | batch 90 | train_loss: 0.00037702
# train: 98it [00:07, 12.41it/s]2026-04-23 18:22:12,037 - INFO - epoch 6 | batch 100 | train_loss: 0.00037245
# train: 108it [00:08, 12.40it/s]2026-04-23 18:22:12,842 - INFO - epoch 6 | batch 110 | train_loss: 0.00070433
# train: 118it [00:09, 12.03it/s]2026-04-23 18:22:13,677 - INFO - epoch 6 | batch 120 | train_loss: 0.00086944
# train: 128it [00:10, 12.36it/s]2026-04-23 18:22:14,483 - INFO - epoch 6 | batch 130 | train_loss: 0.00085086
# train: 138it [00:11, 11.83it/s]2026-04-23 18:22:15,330 - INFO - epoch 6 | batch 140 | train_loss: 0.00081012
# train: 148it [00:12, 12.01it/s]2026-04-23 18:22:16,161 - INFO - epoch 6 | batch 150 | train_loss: 0.00077545
# train: 158it [00:12, 12.26it/s]2026-04-23 18:22:16,974 - INFO - epoch 6 | batch 160 | train_loss: 0.00078119
# train: 168it [00:13, 11.50it/s]2026-04-23 18:22:17,867 - INFO - epoch 6 | batch 170 | train_loss: 0.00075938
# train: 178it [00:14, 11.88it/s]2026-04-23 18:22:18,699 - INFO - epoch 6 | batch 180 | train_loss: 0.00080231
# train: 188it [00:15,  9.98it/s]2026-04-23 18:22:19,697 - INFO - epoch 6 | batch 190 | train_loss: 0.00091493
# train: 198it [00:16, 11.94it/s]2026-04-23 18:22:20,505 - INFO - epoch 6 | batch 200 | train_loss: 0.00095468
# train: 208it [00:17, 12.08it/s]2026-04-23 18:22:21,342 - INFO - epoch 6 | batch 210 | train_loss: 0.00102824
# train: 218it [00:18, 12.05it/s]2026-04-23 18:22:22,171 - INFO - epoch 6 | batch 220 | train_loss: 0.00101268
# train: 228it [00:18, 10.90it/s]2026-04-23 18:22:23,135 - INFO - epoch 6 | batch 230 | train_loss: 0.00100175
# train: 238it [00:19, 11.67it/s]2026-04-23 18:22:23,965 - INFO - epoch 6 | batch 240 | train_loss: 0.00110810
# train: 248it [00:20, 12.29it/s]2026-04-23 18:22:24,773 - INFO - epoch 6 | batch 250 | train_loss: 0.00112056
# train: 258it [00:21, 12.34it/s]2026-04-23 18:22:25,578 - INFO - epoch 6 | batch 260 | train_loss: 0.00119358
# train: 268it [00:22, 12.40it/s]2026-04-23 18:22:26,386 - INFO - epoch 6 | batch 270 | train_loss: 0.00115808
# train: 278it [00:23, 12.42it/s]2026-04-23 18:22:27,190 - INFO - epoch 6 | batch 280 | train_loss: 0.00118206
# train: 288it [00:23, 12.34it/s]2026-04-23 18:22:27,995 - INFO - epoch 6 | batch 290 | train_loss: 0.00132673
# train: 298it [00:24, 12.44it/s]2026-04-23 18:22:28,799 - INFO - epoch 6 | batch 300 | train_loss: 0.00132040
# train: 308it [00:25, 12.47it/s]2026-04-23 18:22:29,601 - INFO - epoch 6 | batch 310 | train_loss: 0.00128797
# train: 318it [00:26, 12.47it/s]2026-04-23 18:22:30,406 - INFO - epoch 6 | batch 320 | train_loss: 0.00126981
# train: 328it [00:27, 12.38it/s]2026-04-23 18:22:31,216 - INFO - epoch 6 | batch 330 | train_loss: 0.00124231
# train: 339it [00:28,  9.43it/s]2026-04-23 18:22:32,332 - INFO - epoch 6 | batch 340 | train_loss: 0.00121504
# train: 349it [00:29, 11.65it/s]2026-04-23 18:22:33,173 - INFO - epoch 6 | batch 350 | train_loss: 0.00121919
# train: 351it [00:29, 11.97it/s]
# valid: 105it [00:06, 16.09it/s]
# Computing metrics: 100%|██████████| 105/105 [00:06<00:00, 16.84it/s]
# 2026-04-23 18:22:46,014 - INFO - ================= epoch end =================
# 2026-04-23 18:22:46,015 - INFO - epoch 6 | train_loss: 0.02035362 | valid_loss: 1.72932115 | valid balanc. acc.: 0.64090647
# 2026-04-23 18:22:46,016 - INFO - metrics:
# {'accuracy': 0.6063132817153067, 'balanced_accuracy': 0.6409064657392329, 'f1': 0.6145772594752187, 'precision': 0.4985808893093661, 'recall': 0.8009118541033434}
# 2026-04-23 18:22:46,158 - INFO - save checkpoint: ..\models_checkpoints/resnet_18_backbone_cv/2026-04-23_18_17_44_full_tuning_patient/fold1/checkpoint/best_model.pth
# train: 8it [00:00, 12.29it/s]2026-04-23 18:22:46,973 - INFO - epoch 7 | batch 10 | train_loss: 0.00376177
# train: 18it [00:01, 12.31it/s]2026-04-23 18:22:47,782 - INFO - epoch 7 | batch 20 | train_loss: 0.00225865
# train: 28it [00:02, 12.38it/s]2026-04-23 18:22:48,590 - INFO - epoch 7 | batch 30 | train_loss: 0.00159624
# train: 38it [00:03, 12.42it/s]2026-04-23 18:22:49,396 - INFO - epoch 7 | batch 40 | train_loss: 0.00133218
# train: 48it [00:03, 12.37it/s]2026-04-23 18:22:50,202 - INFO - epoch 7 | batch 50 | train_loss: 0.00126139
# train: 58it [00:04, 12.01it/s]2026-04-23 18:22:51,040 - INFO - epoch 7 | batch 60 | train_loss: 0.00112367
# train: 68it [00:05, 12.16it/s]2026-04-23 18:22:51,859 - INFO - epoch 7 | batch 70 | train_loss: 0.00100795
# train: 78it [00:06, 12.21it/s]2026-04-23 18:22:52,665 - INFO - epoch 7 | batch 80 | train_loss: 0.00090272
# train: 88it [00:07, 12.32it/s]2026-04-23 18:22:53,476 - INFO - epoch 7 | batch 90 | train_loss: 0.00105686
# train: 98it [00:08, 11.77it/s]2026-04-23 18:22:54,322 - INFO - epoch 7 | batch 100 | train_loss: 0.00108640
# train: 108it [00:08, 12.28it/s]2026-04-23 18:22:55,129 - INFO - epoch 7 | batch 110 | train_loss: 0.00103595
# train: 118it [00:09, 12.40it/s]2026-04-23 18:22:55,938 - INFO - epoch 7 | batch 120 | train_loss: 0.00096413
# train: 128it [00:10, 12.39it/s]2026-04-23 18:22:56,742 - INFO - epoch 7 | batch 130 | train_loss: 0.00089846
# train: 138it [00:11, 12.39it/s]2026-04-23 18:22:57,547 - INFO - epoch 7 | batch 140 | train_loss: 0.00090591
# train: 148it [00:12, 12.33it/s]2026-04-23 18:22:58,367 - INFO - epoch 7 | batch 150 | train_loss: 0.00100775
# train: 158it [00:12, 12.38it/s]2026-04-23 18:22:59,174 - INFO - epoch 7 | batch 160 | train_loss: 0.00095692
# train: 168it [00:13, 12.47it/s]2026-04-23 18:22:59,973 - INFO - epoch 7 | batch 170 | train_loss: 0.00091354
# train: 178it [00:14, 12.45it/s]2026-04-23 18:23:00,778 - INFO - epoch 7 | batch 180 | train_loss: 0.00093477
# train: 188it [00:15, 12.37it/s]2026-04-23 18:23:01,586 - INFO - epoch 7 | batch 190 | train_loss: 0.00090494
# train: 198it [00:16, 12.41it/s]2026-04-23 18:23:02,393 - INFO - epoch 7 | batch 200 | train_loss: 0.00086353
# train: 208it [00:16, 12.39it/s]2026-04-23 18:23:03,196 - INFO - epoch 7 | batch 210 | train_loss: 0.00087069
# train: 218it [00:17, 12.06it/s]2026-04-23 18:23:04,033 - INFO - epoch 7 | batch 220 | train_loss: 0.00100138
# train: 228it [00:18, 12.47it/s]2026-04-23 18:23:04,838 - INFO - epoch 7 | batch 230 | train_loss: 0.00117090
# train: 238it [00:19, 12.38it/s]2026-04-23 18:23:05,642 - INFO - epoch 7 | batch 240 | train_loss: 0.00150018
# train: 248it [00:20, 12.39it/s]2026-04-23 18:23:06,453 - INFO - epoch 7 | batch 250 | train_loss: 0.00151558
# train: 258it [00:20, 12.38it/s]2026-04-23 18:23:07,265 - INFO - epoch 7 | batch 260 | train_loss: 0.00153779
# train: 268it [00:21, 12.24it/s]2026-04-23 18:23:08,077 - INFO - epoch 7 | batch 270 | train_loss: 0.00149655
# train: 278it [00:22, 12.40it/s]2026-04-23 18:23:08,875 - INFO - epoch 7 | batch 280 | train_loss: 0.00144959
# train: 288it [00:23, 12.40it/s]2026-04-23 18:23:09,688 - INFO - epoch 7 | batch 290 | train_loss: 0.00140962
# train: 298it [00:24, 12.42it/s]2026-04-23 18:23:10,491 - INFO - epoch 7 | batch 300 | train_loss: 0.00138519
# train: 308it [00:24, 12.43it/s]2026-04-23 18:23:11,294 - INFO - epoch 7 | batch 310 | train_loss: 0.00145731
# train: 318it [00:25, 12.56it/s]2026-04-23 18:23:12,101 - INFO - epoch 7 | batch 320 | train_loss: 0.00145022
# train: 328it [00:26, 12.41it/s]2026-04-23 18:23:12,905 - INFO - epoch 7 | batch 330 | train_loss: 0.00141931
# train: 338it [00:27, 12.42it/s]2026-04-23 18:23:13,712 - INFO - epoch 7 | batch 340 | train_loss: 0.00143206
# train: 348it [00:28, 12.53it/s]2026-04-23 18:23:14,518 - INFO - epoch 7 | batch 350 | train_loss: 0.00153119
# train: 351it [00:28, 12.35it/s]
# valid: 105it [00:05, 17.50it/s]
# Computing metrics: 100%|██████████| 105/105 [00:05<00:00, 17.55it/s]
# 2026-04-23 18:23:26,574 - INFO - ================= epoch end =================
# 2026-04-23 18:23:26,575 - INFO - epoch 7 | train_loss: 0.02505317 | valid_loss: 1.86018548 | valid balanc. acc.: 0.60615375
# 2026-04-23 18:23:26,575 - INFO - metrics:
# {'accuracy': 0.5670041691483025, 'balanced_accuracy': 0.6061537499739513, 'f1': 0.5876347135564379, 'precision': 0.4687782805429864, 'recall': 0.7872340425531915}
# train: 8it [00:00, 12.53it/s]2026-04-23 18:23:27,369 - INFO - epoch 8 | batch 10 | train_loss: 0.00049946
# train: 18it [00:01, 12.42it/s]2026-04-23 18:23:28,175 - INFO - epoch 8 | batch 20 | train_loss: 0.00051974
# train: 28it [00:02, 12.42it/s]2026-04-23 18:23:28,978 - INFO - epoch 8 | batch 30 | train_loss: 0.00041808
# train: 38it [00:03, 12.44it/s]2026-04-23 18:23:29,784 - INFO - epoch 8 | batch 40 | train_loss: 0.00036310
# train: 48it [00:03, 12.44it/s]2026-04-23 18:23:30,582 - INFO - epoch 8 | batch 50 | train_loss: 0.00031316
# train: 58it [00:04, 11.82it/s]2026-04-23 18:23:31,426 - INFO - epoch 8 | batch 60 | train_loss: 0.00028661
# train: 68it [00:05, 12.27it/s]2026-04-23 18:23:32,233 - INFO - epoch 8 | batch 70 | train_loss: 0.00027584
# train: 78it [00:06, 12.37it/s]2026-04-23 18:23:33,042 - INFO - epoch 8 | batch 80 | train_loss: 0.00025735
# train: 88it [00:07, 12.42it/s]2026-04-23 18:23:33,842 - INFO - epoch 8 | batch 90 | train_loss: 0.00029199
# train: 98it [00:07, 12.43it/s]2026-04-23 18:23:34,650 - INFO - epoch 8 | batch 100 | train_loss: 0.00027053
# train: 108it [00:08, 12.40it/s]2026-04-23 18:23:35,456 - INFO - epoch 8 | batch 110 | train_loss: 0.00025886
# train: 118it [00:09, 11.64it/s]2026-04-23 18:23:36,302 - INFO - epoch 8 | batch 120 | train_loss: 0.00024007
# train: 128it [00:10, 12.17it/s]2026-04-23 18:23:37,111 - INFO - epoch 8 | batch 130 | train_loss: 0.00022689
# train: 138it [00:11, 12.35it/s]2026-04-23 18:23:37,917 - INFO - epoch 8 | batch 140 | train_loss: 0.00026256
# train: 148it [00:11, 12.34it/s]2026-04-23 18:23:38,723 - INFO - epoch 8 | batch 150 | train_loss: 0.00026932
# train: 158it [00:12, 12.39it/s]2026-04-23 18:23:39,522 - INFO - epoch 8 | batch 160 | train_loss: 0.00036230
# train: 168it [00:13, 12.40it/s]2026-04-23 18:23:40,332 - INFO - epoch 8 | batch 170 | train_loss: 0.00035265
# train: 178it [00:14, 12.42it/s]2026-04-23 18:23:41,132 - INFO - epoch 8 | batch 180 | train_loss: 0.00035443
# train: 188it [00:15, 12.50it/s]2026-04-23 18:23:41,934 - INFO - epoch 8 | batch 190 | train_loss: 0.00034933
# train: 198it [00:16, 12.43it/s]2026-04-23 18:23:42,743 - INFO - epoch 8 | batch 200 | train_loss: 0.00033425
# train: 208it [00:16, 12.44it/s]2026-04-23 18:23:43,549 - INFO - epoch 8 | batch 210 | train_loss: 0.00031998
# train: 218it [00:17, 12.30it/s]2026-04-23 18:23:44,364 - INFO - epoch 8 | batch 220 | train_loss: 0.00030697
# train: 228it [00:18, 12.48it/s]2026-04-23 18:23:45,169 - INFO - epoch 8 | batch 230 | train_loss: 0.00036985
# train: 238it [00:19, 12.27it/s]2026-04-23 18:23:45,978 - INFO - epoch 8 | batch 240 | train_loss: 0.00035995
# train: 248it [00:20, 12.30it/s]2026-04-23 18:23:46,902 - INFO - epoch 8 | batch 250 | train_loss: 0.00035596
# train: 258it [00:21, 10.56it/s]2026-04-23 18:23:47,837 - INFO - epoch 8 | batch 260 | train_loss: 0.00037888
# train: 268it [00:21, 11.65it/s]2026-04-23 18:23:48,701 - INFO - epoch 8 | batch 270 | train_loss: 0.00041111
# train: 278it [00:22, 11.74it/s]2026-04-23 18:23:49,549 - INFO - epoch 8 | batch 280 | train_loss: 0.00040504
# train: 288it [00:23, 12.18it/s]2026-04-23 18:23:50,357 - INFO - epoch 8 | batch 290 | train_loss: 0.00044942
# train: 298it [00:24, 12.39it/s]2026-04-23 18:23:51,166 - INFO - epoch 8 | batch 300 | train_loss: 0.00046401
# train: 308it [00:25, 12.33it/s]2026-04-23 18:23:51,978 - INFO - epoch 8 | batch 310 | train_loss: 0.00047798
# train: 318it [00:26, 12.38it/s]2026-04-23 18:23:52,788 - INFO - epoch 8 | batch 320 | train_loss: 0.00054332
# train: 328it [00:26, 12.37it/s]2026-04-23 18:23:53,596 - INFO - epoch 8 | batch 330 | train_loss: 0.00055233
# train: 338it [00:27, 12.22it/s]2026-04-23 18:23:54,427 - INFO - epoch 8 | batch 340 | train_loss: 0.00055355
# train: 348it [00:28, 12.02it/s]2026-04-23 18:23:55,253 - INFO - epoch 8 | batch 350 | train_loss: 0.00054637
# train: 351it [00:28, 12.21it/s]
# valid: 105it [00:06, 16.14it/s]
# Computing metrics: 100%|██████████| 105/105 [00:06<00:00, 16.16it/s]
# 2026-04-23 18:24:08,338 - INFO - ================= epoch end =================
# 2026-04-23 18:24:08,339 - INFO - epoch 8 | train_loss: 0.00920485 | valid_loss: 2.61503417 | valid balanc. acc.: 0.54998824
# 2026-04-23 18:24:08,340 - INFO - metrics:
# {'accuracy': 0.49672424061941634, 'balanced_accuracy': 0.5499882408628527, 'f1': 0.5536185948230322, 'precision': 0.4242914979757085, 'recall': 0.7963525835866262}
# train: 8it [00:00, 12.33it/s]2026-04-23 18:24:09,155 - INFO - epoch 9 | batch 10 | train_loss: 0.00008305
# train: 18it [00:01, 12.40it/s]2026-04-23 18:24:09,963 - INFO - epoch 9 | batch 20 | train_loss: 0.00040204
# train: 28it [00:02, 12.42it/s]2026-04-23 18:24:10,773 - INFO - epoch 9 | batch 30 | train_loss: 0.00029717
# train: 38it [00:03, 11.93it/s]2026-04-23 18:24:11,608 - INFO - epoch 9 | batch 40 | train_loss: 0.00027931
# train: 48it [00:03, 12.32it/s]2026-04-23 18:24:12,416 - INFO - epoch 9 | batch 50 | train_loss: 0.00066620
# train: 58it [00:04, 12.39it/s]2026-04-23 18:24:13,241 - INFO - epoch 9 | batch 60 | train_loss: 0.00112823
# train: 68it [00:05, 12.30it/s]2026-04-23 18:24:14,048 - INFO - epoch 9 | batch 70 | train_loss: 0.00166364
# train: 78it [00:06, 12.35it/s]2026-04-23 18:24:14,859 - INFO - epoch 9 | batch 80 | train_loss: 0.00160762
# train: 88it [00:07, 12.39it/s]2026-04-23 18:24:15,705 - INFO - epoch 9 | batch 90 | train_loss: 0.00148057
# train: 98it [00:08, 11.79it/s]2026-04-23 18:24:16,536 - INFO - epoch 9 | batch 100 | train_loss: 0.00138941
# train: 108it [00:08, 12.32it/s]2026-04-23 18:24:17,341 - INFO - epoch 9 | batch 110 | train_loss: 0.00170682
# train: 118it [00:09, 12.31it/s]2026-04-23 18:24:18,152 - INFO - epoch 9 | batch 120 | train_loss: 0.00168674
# train: 128it [00:10, 11.89it/s]2026-04-23 18:24:19,006 - INFO - epoch 9 | batch 130 | train_loss: 0.00180836
# train: 138it [00:11, 12.28it/s]2026-04-23 18:24:19,813 - INFO - epoch 9 | batch 140 | train_loss: 0.00190339
# train: 148it [00:12, 12.42it/s]2026-04-23 18:24:20,618 - INFO - epoch 9 | batch 150 | train_loss: 0.00180299
# train: 158it [00:12, 12.40it/s]2026-04-23 18:24:21,426 - INFO - epoch 9 | batch 160 | train_loss: 0.00179024
# train: 168it [00:13, 12.42it/s]2026-04-23 18:24:22,232 - INFO - epoch 9 | batch 170 | train_loss: 0.00171762
# train: 178it [00:14, 12.37it/s]2026-04-23 18:24:23,039 - INFO - epoch 9 | batch 180 | train_loss: 0.00164539
# train: 188it [00:15, 12.42it/s]2026-04-23 18:24:23,850 - INFO - epoch 9 | batch 190 | train_loss: 0.00158071
# train: 198it [00:16, 12.34it/s]2026-04-23 18:24:24,666 - INFO - epoch 9 | batch 200 | train_loss: 0.00150361
# train: 208it [00:16, 12.39it/s]2026-04-23 18:24:25,472 - INFO - epoch 9 | batch 210 | train_loss: 0.00149990
# train: 218it [00:17, 12.42it/s]2026-04-23 18:24:26,276 - INFO - epoch 9 | batch 220 | train_loss: 0.00147648
# train: 228it [00:18, 12.41it/s]2026-04-23 18:24:27,083 - INFO - epoch 9 | batch 230 | train_loss: 0.00141995
# train: 238it [00:19, 11.91it/s]2026-04-23 18:24:27,941 - INFO - epoch 9 | batch 240 | train_loss: 0.00136417
# train: 248it [00:20, 12.19it/s]2026-04-23 18:24:28,751 - INFO - epoch 9 | batch 250 | train_loss: 0.00131796
# train: 258it [00:21, 12.41it/s]2026-04-23 18:24:29,556 - INFO - epoch 9 | batch 260 | train_loss: 0.00127335
# train: 268it [00:21, 12.41it/s]2026-04-23 18:24:30,361 - INFO - epoch 9 | batch 270 | train_loss: 0.00122855
# train: 278it [00:22, 12.43it/s]2026-04-23 18:24:31,165 - INFO - epoch 9 | batch 280 | train_loss: 0.00118900
# train: 288it [00:23, 11.74it/s]2026-04-23 18:24:32,011 - INFO - epoch 9 | batch 290 | train_loss: 0.00114940
# train: 298it [00:24, 12.28it/s]2026-04-23 18:24:32,817 - INFO - epoch 9 | batch 300 | train_loss: 0.00111401
# train: 308it [00:25, 12.39it/s]2026-04-23 18:24:33,624 - INFO - epoch 9 | batch 310 | train_loss: 0.00107971
# train: 318it [00:25, 12.43it/s]2026-04-23 18:24:34,427 - INFO - epoch 9 | batch 320 | train_loss: 0.00105384
# train: 328it [00:26, 12.02it/s]2026-04-23 18:24:35,259 - INFO - epoch 9 | batch 330 | train_loss: 0.00102696
# train: 338it [00:27, 12.36it/s]2026-04-23 18:24:36,064 - INFO - epoch 9 | batch 340 | train_loss: 0.00101183
# train: 348it [00:28, 12.40it/s]2026-04-23 18:24:36,869 - INFO - epoch 9 | batch 350 | train_loss: 0.00107564
# train: 351it [00:28, 12.28it/s]
# valid: 105it [00:06, 16.89it/s]
# Computing metrics: 100%|██████████| 105/105 [00:06<00:00, 17.04it/s]
# 2026-04-23 18:24:49,326 - INFO - ================= epoch end =================
# 2026-04-23 18:24:49,327 - INFO - epoch 9 | train_loss: 0.02389205 | valid_loss: 4.57851262 | valid balanc. acc.: 0.56057593
# 2026-04-23 18:24:49,328 - INFO - metrics:
# {'accuracy': 0.50565812983919, 'balanced_accuracy': 0.5605759297905087, 'f1': 0.5636172450052577, 'precision': 0.43086816720257237, 'recall': 0.8145896656534954}
# train: 8it [00:00, 12.55it/s]2026-04-23 18:24:50,123 - INFO - epoch 10 | batch 10 | train_loss: 0.00621521
# train: 18it [00:01, 12.45it/s]2026-04-23 18:24:50,928 - INFO - epoch 10 | batch 20 | train_loss: 0.00394308
# train: 28it [00:02, 12.23it/s]2026-04-23 18:24:51,760 - INFO - epoch 10 | batch 30 | train_loss: 0.00269620
# train: 38it [00:03, 12.41it/s]2026-04-23 18:24:52,562 - INFO - epoch 10 | batch 40 | train_loss: 0.00209870
# train: 48it [00:03, 12.42it/s]2026-04-23 18:24:53,368 - INFO - epoch 10 | batch 50 | train_loss: 0.00169564
# train: 58it [00:04, 12.41it/s]2026-04-23 18:24:54,174 - INFO - epoch 10 | batch 60 | train_loss: 0.00145759
# train: 68it [00:05, 12.40it/s]2026-04-23 18:24:54,984 - INFO - epoch 10 | batch 70 | train_loss: 0.00133804
# train: 78it [00:06, 12.40it/s]2026-04-23 18:24:55,791 - INFO - epoch 10 | batch 80 | train_loss: 0.00119825
# train: 88it [00:07, 12.40it/s]2026-04-23 18:24:56,597 - INFO - epoch 10 | batch 90 | train_loss: 0.00110090
# train: 98it [00:07, 12.41it/s]2026-04-23 18:24:57,402 - INFO - epoch 10 | batch 100 | train_loss: 0.00103357
# train: 108it [00:08, 12.43it/s]2026-04-23 18:24:58,207 - INFO - epoch 10 | batch 110 | train_loss: 0.00094493
# train: 118it [00:09, 12.22it/s]2026-04-23 18:24:59,024 - INFO - epoch 10 | batch 120 | train_loss: 0.00088752
# train: 128it [00:10, 12.40it/s]2026-04-23 18:24:59,830 - INFO - epoch 10 | batch 130 | train_loss: 0.00082380
# train: 138it [00:11, 12.44it/s]2026-04-23 18:25:00,634 - INFO - epoch 10 | batch 140 | train_loss: 0.00077787
# train: 148it [00:11, 12.43it/s]2026-04-23 18:25:01,439 - INFO - epoch 10 | batch 150 | train_loss: 0.00076258
# train: 158it [00:12, 12.44it/s]2026-04-23 18:25:02,241 - INFO - epoch 10 | batch 160 | train_loss: 0.00073335
# train: 168it [00:13, 12.46it/s]2026-04-23 18:25:03,047 - INFO - epoch 10 | batch 170 | train_loss: 0.00070200
# train: 178it [00:14, 12.44it/s]2026-04-23 18:25:03,852 - INFO - epoch 10 | batch 180 | train_loss: 0.00067333
# train: 188it [00:15, 12.40it/s]2026-04-23 18:25:04,658 - INFO - epoch 10 | batch 190 | train_loss: 0.00064085
# train: 198it [00:15, 12.40it/s]2026-04-23 18:25:05,463 - INFO - epoch 10 | batch 200 | train_loss: 0.00062584
# train: 208it [00:16, 12.42it/s]2026-04-23 18:25:06,268 - INFO - epoch 10 | batch 210 | train_loss: 0.00060356
# train: 218it [00:17, 11.70it/s]2026-04-23 18:25:07,152 - INFO - epoch 10 | batch 220 | train_loss: 0.00061274
# train: 228it [00:18, 12.32it/s]2026-04-23 18:25:07,957 - INFO - epoch 10 | batch 230 | train_loss: 0.00059596
# train: 238it [00:19, 12.30it/s]2026-04-23 18:25:08,768 - INFO - epoch 10 | batch 240 | train_loss: 0.00067812
# train: 248it [00:20, 12.43it/s]2026-04-23 18:25:09,575 - INFO - epoch 10 | batch 250 | train_loss: 0.00065735
# train: 258it [00:20, 12.40it/s]2026-04-23 18:25:10,378 - INFO - epoch 10 | batch 260 | train_loss: 0.00064416
# train: 268it [00:21, 12.45it/s]2026-04-23 18:25:11,182 - INFO - epoch 10 | batch 270 | train_loss: 0.00062157
# train: 278it [00:22, 12.42it/s]2026-04-23 18:25:11,988 - INFO - epoch 10 | batch 280 | train_loss: 0.00060652
# train: 288it [00:23, 12.41it/s]2026-04-23 18:25:12,791 - INFO - epoch 10 | batch 290 | train_loss: 0.00059842
# train: 298it [00:24, 12.15it/s]2026-04-23 18:25:13,616 - INFO - epoch 10 | batch 300 | train_loss: 0.00058211
# train: 308it [00:24, 12.37it/s]2026-04-23 18:25:14,423 - INFO - epoch 10 | batch 310 | train_loss: 0.00056480
# train: 318it [00:25, 12.38it/s]2026-04-23 18:25:15,229 - INFO - epoch 10 | batch 320 | train_loss: 0.00055129
# train: 328it [00:26, 12.00it/s]2026-04-23 18:25:16,062 - INFO - epoch 10 | batch 330 | train_loss: 0.00053605
# train: 338it [00:27, 12.34it/s]2026-04-23 18:25:16,867 - INFO - epoch 10 | batch 340 | train_loss: 0.00052255
# train: 348it [00:28, 12.41it/s]2026-04-23 18:25:17,672 - INFO - epoch 10 | batch 350 | train_loss: 0.00051379
# train: 351it [00:28, 12.36it/s]
# valid: 105it [00:06, 17.16it/s]
# Computing metrics: 100%|██████████| 105/105 [00:06<00:00, 17.02it/s]
# 2026-04-23 18:25:30,038 - INFO - ================= epoch end =================
# 2026-04-23 18:25:30,039 - INFO - epoch 10 | train_loss: 0.01276068 | valid_loss: 4.20414571 | valid balanc. acc.: 0.57526666
# 2026-04-23 18:25:30,040 - INFO - metrics:
# {'accuracy': 0.5139964264443121, 'balanced_accuracy': 0.5752666644835357, 'f1': 0.5806783144912642, 'precision': 0.4386645962732919, 'recall': 0.8586626139817629}
# 2026-04-23 18:25:30,045 - INFO - Fold 2
# 2026-04-23 18:25:30,056 - INFO -
#     ======= about folds =======
#     ((5771, 8), (1509, 8))
#     set()
#     label
# 0    2993
# 1    2778
# Name: image_path, dtype: int64
#     label
# 0    647
# 1    862
# Name: image_path, dtype: int64
#
# 2026-04-23 18:25:30,288 - INFO -
#     Всего параметров: 11,177,538
#     Обучаемых:       11,177,538
#
# train: 8it [00:00, 12.38it/s]2026-04-23 18:25:31,097 - INFO - epoch 1 | batch 10 | train_loss: 0.05031802
# train: 18it [00:01, 12.38it/s]2026-04-23 18:25:31,906 - INFO - epoch 1 | batch 20 | train_loss: 0.05025048
# train: 28it [00:02, 12.42it/s]2026-04-23 18:25:32,711 - INFO - epoch 1 | batch 30 | train_loss: 0.04529735
# train: 38it [00:03, 12.43it/s]2026-04-23 18:25:33,516 - INFO - epoch 1 | batch 40 | train_loss: 0.03999170
# train: 48it [00:03, 12.43it/s]2026-04-23 18:25:34,321 - INFO - epoch 1 | batch 50 | train_loss: 0.03616018
# train: 58it [00:04, 12.09it/s]2026-04-23 18:25:35,155 - INFO - epoch 1 | batch 60 | train_loss: 0.03580594
# train: 68it [00:05, 12.38it/s]2026-04-23 18:25:35,960 - INFO - epoch 1 | batch 70 | train_loss: 0.03388265
# train: 78it [00:06, 12.44it/s]2026-04-23 18:25:36,765 - INFO - epoch 1 | batch 80 | train_loss: 0.03242331
# train: 88it [00:07, 12.41it/s]2026-04-23 18:25:37,571 - INFO - epoch 1 | batch 90 | train_loss: 0.03080908
# train: 98it [00:07, 12.43it/s]2026-04-23 18:25:38,376 - INFO - epoch 1 | batch 100 | train_loss: 0.03017285
# train: 108it [00:08, 12.45it/s]2026-04-23 18:25:39,180 - INFO - epoch 1 | batch 110 | train_loss: 0.02893485
# train: 118it [00:09, 12.41it/s]2026-04-23 18:25:39,987 - INFO - epoch 1 | batch 120 | train_loss: 0.02789335
# train: 128it [00:10, 12.41it/s]2026-04-23 18:25:40,793 - INFO - epoch 1 | batch 130 | train_loss: 0.02662435
# train: 138it [00:11, 12.43it/s]2026-04-23 18:25:41,597 - INFO - epoch 1 | batch 140 | train_loss: 0.02534827
# train: 148it [00:11, 12.44it/s]2026-04-23 18:25:42,402 - INFO - epoch 1 | batch 150 | train_loss: 0.02445390
# train: 158it [00:12, 12.45it/s]2026-04-23 18:25:43,206 - INFO - epoch 1 | batch 160 | train_loss: 0.02358633
# train: 168it [00:13, 12.44it/s]2026-04-23 18:25:44,014 - INFO - epoch 1 | batch 170 | train_loss: 0.02261099
# train: 178it [00:14, 12.33it/s]2026-04-23 18:25:44,828 - INFO - epoch 1 | batch 180 | train_loss: 0.02175391
# train: 188it [00:15, 12.41it/s]2026-04-23 18:25:45,634 - INFO - epoch 1 | batch 190 | train_loss: 0.02121251
# train: 198it [00:15, 12.42it/s]2026-04-23 18:25:46,439 - INFO - epoch 1 | batch 200 | train_loss: 0.02066351
# train: 208it [00:16, 12.43it/s]2026-04-23 18:25:47,242 - INFO - epoch 1 | batch 210 | train_loss: 0.02008426
# train: 218it [00:17, 12.44it/s]2026-04-23 18:25:48,047 - INFO - epoch 1 | batch 220 | train_loss: 0.01946334
# train: 228it [00:18, 12.45it/s]2026-04-23 18:25:48,856 - INFO - epoch 1 | batch 230 | train_loss: 0.01891452
# train: 238it [00:19, 12.39it/s]2026-04-23 18:25:49,661 - INFO - epoch 1 | batch 240 | train_loss: 0.01841400
# train: 248it [00:20, 12.40it/s]2026-04-23 18:25:50,466 - INFO - epoch 1 | batch 250 | train_loss: 0.01805078
# train: 258it [00:20, 12.40it/s]2026-04-23 18:25:51,303 - INFO - epoch 1 | batch 260 | train_loss: 0.01779065
# train: 268it [00:21, 12.14it/s]2026-04-23 18:25:52,124 - INFO - epoch 1 | batch 270 | train_loss: 0.01751863
# train: 278it [00:22, 12.35it/s]2026-04-23 18:25:52,930 - INFO - epoch 1 | batch 280 | train_loss: 0.01718328
# train: 288it [00:23, 12.28it/s]2026-04-23 18:25:53,745 - INFO - epoch 1 | batch 290 | train_loss: 0.01684561
# train: 298it [00:24, 12.40it/s]2026-04-23 18:25:54,551 - INFO - epoch 1 | batch 300 | train_loss: 0.01647680
# train: 308it [00:24, 12.43it/s]2026-04-23 18:25:55,356 - INFO - epoch 1 | batch 310 | train_loss: 0.01603170
# train: 318it [00:25, 12.43it/s]2026-04-23 18:25:56,161 - INFO - epoch 1 | batch 320 | train_loss: 0.01590698
# ...
# train: 218it [00:18, 11.54it/s]2026-04-23 18:50:51,795 - INFO - epoch 7 | batch 220 | train_loss: 0.00107939
# train: 228it [00:18, 12.15it/s]2026-04-23 18:50:52,608 - INFO - epoch 7 | batch 230 | train_loss: 0.00106131
# train: 238it [00:19, 12.29it/s]2026-04-23 18:50:53,419 - INFO - epoch 7 | batch 240 | train_loss: 0.00103169
# train: 248it [00:20, 12.05it/s]2026-04-23 18:50:54,260 - INFO - epoch 7 | batch 250 | train_loss: 0.00103822
# train: 258it [00:21, 11.78it/s]2026-04-23 18:50:55,115 - INFO - epoch 7 | batch 260 | train_loss: 0.00101223
# train: 268it [00:22, 12.18it/s]2026-04-23 18:50:55,931 - INFO - epoch 7 | batch 270 | train_loss: 0.00097796
# train: 278it [00:23, 12.13it/s]2026-04-23 18:50:56,763 - INFO - epoch 7 | batch 280 | train_loss: 0.00094832
# train: 288it [00:23, 12.16it/s]2026-04-23 18:50:57,593 - INFO - epoch 7 | batch 290 | train_loss: 0.00092085
# train: 298it [00:24, 11.51it/s]2026-04-23 18:50:58,493 - INFO - epoch 7 | batch 300 | train_loss: 0.00089685
# train: 308it [00:25, 12.33it/s]2026-04-23 18:50:59,296 - INFO - epoch 7 | batch 310 | train_loss: 0.00087407
# train: 318it [00:26, 12.35it/s]2026-04-23 18:51:00,103 - INFO - epoch 7 | batch 320 | train_loss: 0.00085032
# train: 328it [00:27, 12.39it/s]2026-04-23 18:51:00,909 - INFO - epoch 7 | batch 330 | train_loss: 0.00083957
# train: 338it [00:28, 12.20it/s]2026-04-23 18:51:01,736 - INFO - epoch 7 | batch 340 | train_loss: 0.00081628
# train: 348it [00:28, 12.43it/s]2026-04-23 18:51:02,538 - INFO - epoch 7 | batch 350 | train_loss: 0.00083078
# train: 358it [00:29, 12.41it/s]2026-04-23 18:51:03,346 - INFO - epoch 7 | batch 360 | train_loss: 0.00083510
# train: 368it [00:30, 12.43it/s]2026-04-23 18:51:04,150 - INFO - epoch 7 | batch 370 | train_loss: 0.00082638
# train: 371it [00:30, 12.07it/s]
# valid: 85it [00:05, 16.82it/s]
# Computing metrics: 100%|██████████| 85/85 [00:05<00:00, 16.98it/s]
# 2026-04-23 18:51:14,303 - INFO - ================= epoch end =================
# 2026-04-23 18:51:14,304 - INFO - epoch 7 | train_loss: 0.01318808 | valid_loss: 2.14277606 | valid balanc. acc.: 0.57616567
# 2026-04-23 18:51:14,305 - INFO - metrics:
# {'accuracy': 0.5799557848194546, 'balanced_accuracy': 0.5761656691051504, 'f1': 0.64375, 'precision': 0.5684326710816777, 'recall': 0.7420749279538905}
# train: 8it [00:00, 12.51it/s]2026-04-23 18:51:15,101 - INFO - epoch 8 | batch 10 | train_loss: 0.00043793
# train: 18it [00:01, 12.46it/s]2026-04-23 18:51:15,905 - INFO - epoch 8 | batch 20 | train_loss: 0.00192961
# train: 28it [00:02, 12.03it/s]2026-04-23 18:51:16,747 - INFO - epoch 8 | batch 30 | train_loss: 0.00344712
# train: 38it [00:03, 12.38it/s]2026-04-23 18:51:17,550 - INFO - epoch 8 | batch 40 | train_loss: 0.00272703
# train: 48it [00:03, 12.49it/s]2026-04-23 18:51:18,354 - INFO - epoch 8 | batch 50 | train_loss: 0.00246855
# train: 58it [00:04, 12.42it/s]2026-04-23 18:51:19,159 - INFO - epoch 8 | batch 60 | train_loss: 0.00209518
# train: 68it [00:05, 12.27it/s]2026-04-23 18:51:19,978 - INFO - epoch 8 | batch 70 | train_loss: 0.00214773
# train: 78it [00:06, 12.38it/s]2026-04-23 18:51:20,787 - INFO - epoch 8 | batch 80 | train_loss: 0.00259320
# train: 88it [00:07, 12.36it/s]2026-04-23 18:51:21,598 - INFO - epoch 8 | batch 90 | train_loss: 0.00255066
# train: 98it [00:08, 11.53it/s]2026-04-23 18:51:22,472 - INFO - epoch 8 | batch 100 | train_loss: 0.00249002
# train: 108it [00:09, 10.28it/s]2026-04-23 18:51:23,488 - INFO - epoch 8 | batch 110 | train_loss: 0.00231868
# train: 118it [00:09, 11.94it/s]2026-04-23 18:51:24,303 - INFO - epoch 8 | batch 120 | train_loss: 0.00214797
# train: 128it [00:10, 12.26it/s]2026-04-23 18:51:25,111 - INFO - epoch 8 | batch 130 | train_loss: 0.00198628
# train: 138it [00:11, 11.97it/s]2026-04-23 18:51:25,954 - INFO - epoch 8 | batch 140 | train_loss: 0.00189429
# train: 148it [00:12, 11.70it/s]2026-04-23 18:51:26,803 - INFO - epoch 8 | batch 150 | train_loss: 0.00186902
# train: 158it [00:13, 12.22it/s]2026-04-23 18:51:27,613 - INFO - epoch 8 | batch 160 | train_loss: 0.00181759
# train: 168it [00:13, 12.10it/s]2026-04-23 18:51:28,455 - INFO - epoch 8 | batch 170 | train_loss: 0.00172825
# train: 178it [00:14, 12.31it/s]2026-04-23 18:51:29,263 - INFO - epoch 8 | batch 180 | train_loss: 0.00163828
# train: 188it [00:15, 12.04it/s]2026-04-23 18:51:30,105 - INFO - epoch 8 | batch 190 | train_loss: 0.00155378
# train: 198it [00:16, 12.33it/s]2026-04-23 18:51:30,913 - INFO - epoch 8 | batch 200 | train_loss: 0.00149148
# train: 208it [00:17, 12.36it/s]2026-04-23 18:51:31,722 - INFO - epoch 8 | batch 210 | train_loss: 0.00145262
# train: 218it [00:18, 12.21it/s]2026-04-23 18:51:32,529 - INFO - epoch 8 | batch 220 | train_loss: 0.00139112
# train: 228it [00:18, 12.31it/s]2026-04-23 18:51:33,351 - INFO - epoch 8 | batch 230 | train_loss: 0.00134204
# train: 238it [00:19, 12.42it/s]2026-04-23 18:51:34,154 - INFO - epoch 8 | batch 240 | train_loss: 0.00129788
# train: 248it [00:20, 12.38it/s]2026-04-23 18:51:34,963 - INFO - epoch 8 | batch 250 | train_loss: 0.00126528
# train: 258it [00:21, 12.37it/s]2026-04-23 18:51:35,773 - INFO - epoch 8 | batch 260 | train_loss: 0.00138866
# train: 268it [00:22, 11.99it/s]2026-04-23 18:51:36,621 - INFO - epoch 8 | batch 270 | train_loss: 0.00139572
# train: 278it [00:22, 12.18it/s]2026-04-23 18:51:37,447 - INFO - epoch 8 | batch 280 | train_loss: 0.00145142
# train: 288it [00:23, 12.39it/s]2026-04-23 18:51:38,249 - INFO - epoch 8 | batch 290 | train_loss: 0.00144859
# train: 298it [00:24, 12.36it/s]2026-04-23 18:51:39,060 - INFO - epoch 8 | batch 300 | train_loss: 0.00167922
# train: 308it [00:25, 12.21it/s]2026-04-23 18:51:39,882 - INFO - epoch 8 | batch 310 | train_loss: 0.00173929
# train: 318it [00:26, 12.39it/s]2026-04-23 18:51:40,689 - INFO - epoch 8 | batch 320 | train_loss: 0.00172197
# train: 328it [00:27, 12.43it/s]2026-04-23 18:51:41,495 - INFO - epoch 8 | batch 330 | train_loss: 0.00171149
# train: 338it [00:27, 12.38it/s]2026-04-23 18:51:42,301 - INFO - epoch 8 | batch 340 | train_loss: 0.00168295
# train: 348it [00:28, 11.19it/s]2026-04-23 18:51:43,209 - INFO - epoch 8 | batch 350 | train_loss: 0.00167303
# train: 358it [00:29, 11.88it/s]2026-04-23 18:51:44,046 - INFO - epoch 8 | batch 360 | train_loss: 0.00164262
# train: 368it [00:30, 11.18it/s]2026-04-23 18:51:44,933 - INFO - epoch 8 | batch 370 | train_loss: 0.00160358
# train: 371it [00:30, 12.09it/s]
# valid: 85it [00:05, 14.19it/s]
# Computing metrics: 100%|██████████| 85/85 [00:05<00:00, 15.80it/s]
# 2026-04-23 18:51:56,385 - INFO - ================= epoch end =================
# 2026-04-23 18:51:56,387 - INFO - epoch 8 | train_loss: 0.03373872 | valid_loss: 1.57806185 | valid balanc. acc.: 0.68243096
# 2026-04-23 18:51:56,388 - INFO - metrics:
# {'accuracy': 0.6875460574797347, 'balanced_accuracy': 0.6824309639617319, 'f1': 0.7479191438763377, 'precision': 0.6366396761133604, 'recall': 0.9063400576368876}
# train: 9it [00:00, 11.45it/s]2026-04-23 18:51:57,323 - INFO - epoch 9 | batch 10 | train_loss: 0.00373572
# train: 19it [00:01, 12.17it/s]2026-04-23 18:51:58,142 - INFO - epoch 9 | batch 20 | train_loss: 0.00260827
# train: 29it [00:02, 12.26it/s]2026-04-23 18:51:58,957 - INFO - epoch 9 | batch 30 | train_loss: 0.00179910
# train: 39it [00:03, 12.26it/s]2026-04-23 18:51:59,777 - INFO - epoch 9 | batch 40 | train_loss: 0.00170536
# train: 49it [00:04, 11.32it/s]2026-04-23 18:52:00,670 - INFO - epoch 9 | batch 50 | train_loss: 0.00142513
# train: 59it [00:05, 10.56it/s]2026-04-23 18:52:01,675 - INFO - epoch 9 | batch 60 | train_loss: 0.00126582
# train: 69it [00:06, 11.62it/s]2026-04-23 18:52:02,499 - INFO - epoch 9 | batch 70 | train_loss: 0.00109403
# train: 79it [00:06, 12.22it/s]2026-04-23 18:52:03,309 - INFO - epoch 9 | batch 80 | train_loss: 0.00096702
# train: 89it [00:07, 12.30it/s]2026-04-23 18:52:04,120 - INFO - epoch 9 | batch 90 | train_loss: 0.00088253
# train: 99it [00:08, 11.25it/s]2026-04-23 18:52:04,991 - INFO - epoch 9 | batch 100 | train_loss: 0.00089857
# train: 109it [00:09, 12.11it/s]2026-04-23 18:52:05,801 - INFO - epoch 9 | batch 110 | train_loss: 0.00087339
# train: 119it [00:10, 10.95it/s]2026-04-23 18:52:06,749 - INFO - epoch 9 | batch 120 | train_loss: 0.00089653
# train: 129it [00:11, 11.94it/s]2026-04-23 18:52:07,591 - INFO - epoch 9 | batch 130 | train_loss: 0.00088888
# train: 139it [00:11, 11.86it/s]2026-04-23 18:52:08,425 - INFO - epoch 9 | batch 140 | train_loss: 0.00083272
# train: 149it [00:12, 12.25it/s]2026-04-23 18:52:09,239 - INFO - epoch 9 | batch 150 | train_loss: 0.00139579
# train: 159it [00:13, 12.15it/s]2026-04-23 18:52:10,055 - INFO - epoch 9 | batch 160 | train_loss: 0.00134385
# train: 169it [00:14, 12.44it/s]2026-04-23 18:52:10,855 - INFO - epoch 9 | batch 170 | train_loss: 0.00128089
# train: 179it [00:15, 12.31it/s]2026-04-23 18:52:11,672 - INFO - epoch 9 | batch 180 | train_loss: 0.00124843
# train: 189it [00:16, 12.29it/s]2026-04-23 18:52:12,475 - INFO - epoch 9 | batch 190 | train_loss: 0.00118657
# train: 199it [00:16, 12.40it/s]2026-04-23 18:52:13,285 - INFO - epoch 9 | batch 200 | train_loss: 0.00114046
# train: 209it [00:17, 12.37it/s]2026-04-23 18:52:14,097 - INFO - epoch 9 | batch 210 | train_loss: 0.00109448
# train: 219it [00:18, 12.18it/s]2026-04-23 18:52:14,925 - INFO - epoch 9 | batch 220 | train_loss: 0.00109403
# train: 229it [00:19, 11.90it/s]2026-04-23 18:52:15,783 - INFO - epoch 9 | batch 230 | train_loss: 0.00105098
# train: 239it [00:20, 11.07it/s]2026-04-23 18:52:16,677 - INFO - epoch 9 | batch 240 | train_loss: 0.00101059
# train: 249it [00:21, 11.65it/s]2026-04-23 18:52:17,591 - INFO - epoch 9 | batch 250 | train_loss: 0.00099469
# train: 259it [00:21, 12.08it/s]2026-04-23 18:52:18,403 - INFO - epoch 9 | batch 260 | train_loss: 0.00096008
# train: 269it [00:22, 12.32it/s]2026-04-23 18:52:19,215 - INFO - epoch 9 | batch 270 | train_loss: 0.00093203
# train: 279it [00:23, 11.95it/s]2026-04-23 18:52:20,041 - INFO - epoch 9 | batch 280 | train_loss: 0.00096447
# train: 289it [00:24, 10.20it/s]2026-04-23 18:52:21,007 - INFO - epoch 9 | batch 290 | train_loss: 0.00094001
# train: 299it [00:25, 11.53it/s]2026-04-23 18:52:21,840 - INFO - epoch 9 | batch 300 | train_loss: 0.00093460
# train: 309it [00:26, 12.03it/s]2026-04-23 18:52:22,677 - INFO - epoch 9 | batch 310 | train_loss: 0.00090798
# train: 319it [00:27, 12.07it/s]2026-04-23 18:52:23,519 - INFO - epoch 9 | batch 320 | train_loss: 0.00091157
# train: 329it [00:27, 11.22it/s]2026-04-23 18:52:24,453 - INFO - epoch 9 | batch 330 | train_loss: 0.00088783
# train: 339it [00:28, 12.10it/s]2026-04-23 18:52:25,263 - INFO - epoch 9 | batch 340 | train_loss: 0.00089887
# train: 349it [00:29, 12.04it/s]2026-04-23 18:52:26,095 - INFO - epoch 9 | batch 350 | train_loss: 0.00088739
# train: 359it [00:30, 11.45it/s]2026-04-23 18:52:26,982 - INFO - epoch 9 | batch 360 | train_loss: 0.00088804
# train: 369it [00:31, 11.56it/s]2026-04-23 18:52:27,836 - INFO - epoch 9 | batch 370 | train_loss: 0.00090317
# train: 371it [00:31, 11.77it/s]
# valid: 85it [00:05, 14.69it/s]
# Computing metrics: 100%|██████████| 85/85 [00:05<00:00, 15.17it/s]
# 2026-04-23 18:52:39,307 - INFO - ================= epoch end =================
# 2026-04-23 18:52:39,309 - INFO - epoch 9 | train_loss: 0.02025546 | valid_loss: 5.54824283 | valid balanc. acc.: 0.55543421
# 2026-04-23 18:52:39,310 - INFO - metrics:
# {'accuracy': 0.5467943994104643, 'balanced_accuracy': 0.5554342109266672, 'f1': 0.2857142857142857, 'precision': 0.7365269461077845, 'recall': 0.17723342939481268}
# train: 8it [00:00, 10.89it/s]2026-04-23 18:52:40,178 - INFO - epoch 10 | batch 10 | train_loss: 0.01684851
# train: 18it [00:01, 12.16it/s]2026-04-23 18:52:40,989 - INFO - epoch 10 | batch 20 | train_loss: 0.00863721
# train: 28it [00:02, 12.23it/s]2026-04-23 18:52:41,806 - INFO - epoch 10 | batch 30 | train_loss: 0.00598677
# train: 38it [00:03, 12.32it/s]2026-04-23 18:52:42,618 - INFO - epoch 10 | batch 40 | train_loss: 0.00556953
# train: 48it [00:04, 11.37it/s]2026-04-23 18:52:43,563 - INFO - epoch 10 | batch 50 | train_loss: 0.00483000
# train: 58it [00:04, 11.79it/s]2026-04-23 18:52:44,375 - INFO - epoch 10 | batch 60 | train_loss: 0.00408869
# train: 68it [00:05, 12.16it/s]2026-04-23 18:52:45,192 - INFO - epoch 10 | batch 70 | train_loss: 0.00360099
# train: 78it [00:06, 12.24it/s]2026-04-23 18:52:46,005 - INFO - epoch 10 | batch 80 | train_loss: 0.00319299
# train: 88it [00:07, 11.69it/s]2026-04-23 18:52:46,862 - INFO - epoch 10 | batch 90 | train_loss: 0.00289671
# train: 98it [00:08, 12.01it/s]2026-04-23 18:52:47,696 - INFO - epoch 10 | batch 100 | train_loss: 0.00273129
# train: 108it [00:09, 11.88it/s]2026-04-23 18:52:48,530 - INFO - epoch 10 | batch 110 | train_loss: 0.00253755
# train: 118it [00:09, 12.29it/s]2026-04-23 18:52:49,343 - INFO - epoch 10 | batch 120 | train_loss: 0.00239174
# train: 128it [00:10, 12.22it/s]2026-04-23 18:52:50,171 - INFO - epoch 10 | batch 130 | train_loss: 0.00224631
# train: 138it [00:11, 12.33it/s]2026-04-23 18:52:50,979 - INFO - epoch 10 | batch 140 | train_loss: 0.00210076
# train: 148it [00:12, 12.12it/s]2026-04-23 18:52:51,813 - INFO - epoch 10 | batch 150 | train_loss: 0.00197168
# train: 158it [00:13, 12.24it/s]2026-04-23 18:52:52,637 - INFO - epoch 10 | batch 160 | train_loss: 0.00186466
# train: 168it [00:13, 12.17it/s]2026-04-23 18:52:53,451 - INFO - epoch 10 | batch 170 | train_loss: 0.00176355
# train: 178it [00:14, 12.31it/s]2026-04-23 18:52:54,261 - INFO - epoch 10 | batch 180 | train_loss: 0.00168319
# train: 188it [00:15, 12.35it/s]2026-04-23 18:52:55,070 - INFO - epoch 10 | batch 190 | train_loss: 0.00172899
# train: 198it [00:16, 11.86it/s]2026-04-23 18:52:55,901 - INFO - epoch 10 | batch 200 | train_loss: 0.00176479
# train: 208it [00:17, 12.24it/s]2026-04-23 18:52:56,717 - INFO - epoch 10 | batch 210 | train_loss: 0.00169194
# train: 218it [00:18, 12.17it/s]2026-04-23 18:52:57,532 - INFO - epoch 10 | batch 220 | train_loss: 0.00162136
# train: 228it [00:18, 12.33it/s]2026-04-23 18:52:58,375 - INFO - epoch 10 | batch 230 | train_loss: 0.00155512
# train: 238it [00:19, 11.56it/s]2026-04-23 18:52:59,234 - INFO - epoch 10 | batch 240 | train_loss: 0.00150337
# train: 248it [00:20, 12.18it/s]2026-04-23 18:53:00,046 - INFO - epoch 10 | batch 250 | train_loss: 0.00145481
# train: 258it [00:21, 12.34it/s]2026-04-23 18:53:00,856 - INFO - epoch 10 | batch 260 | train_loss: 0.00157383
# train: 268it [00:22, 12.34it/s]2026-04-23 18:53:01,666 - INFO - epoch 10 | batch 270 | train_loss: 0.00155742
# train: 278it [00:23, 11.99it/s]2026-04-23 18:53:02,508 - INFO - epoch 10 | batch 280 | train_loss: 0.00152030
# train: 288it [00:23, 12.14it/s]2026-04-23 18:53:03,326 - INFO - epoch 10 | batch 290 | train_loss: 0.00147182
# train: 298it [00:24, 12.30it/s]2026-04-23 18:53:04,135 - INFO - epoch 10 | batch 300 | train_loss: 0.00142590
# train: 308it [00:25, 12.33it/s]2026-04-23 18:53:04,960 - INFO - epoch 10 | batch 310 | train_loss: 0.00138223
# train: 318it [00:26, 12.10it/s]2026-04-23 18:53:05,785 - INFO - epoch 10 | batch 320 | train_loss: 0.00134190
# train: 328it [00:27, 12.29it/s]2026-04-23 18:53:06,657 - INFO - epoch 10 | batch 330 | train_loss: 0.00132767
# train: 338it [00:27, 11.98it/s]2026-04-23 18:53:07,467 - INFO - epoch 10 | batch 340 | train_loss: 0.00129328
# train: 348it [00:28, 11.71it/s]2026-04-23 18:53:08,303 - INFO - epoch 10 | batch 350 | train_loss: 0.00126777
# train: 358it [00:29, 12.07it/s]2026-04-23 18:53:09,122 - INFO - epoch 10 | batch 360 | train_loss: 0.00123467
# train: 368it [00:30, 12.29it/s]2026-04-23 18:53:09,934 - INFO - epoch 10 | batch 370 | train_loss: 0.00121540
# train: 371it [00:30, 12.09it/s]
# valid: 85it [00:05, 15.54it/s]
# Computing metrics: 100%|██████████| 85/85 [00:05<00:00, 15.72it/s]
# 2026-04-23 18:53:20,891 - INFO - ================= epoch end =================
# 2026-04-23 18:53:20,892 - INFO - epoch 10 | train_loss: 0.01939613 | valid_loss: 2.02188696 | valid balanc. acc.: 0.60614793
# 2026-04-23 18:53:20,893 - INFO - metrics:
# {'accuracy': 0.6123802505526897, 'balanced_accuracy': 0.6061479346781941, 'f1': 0.6987399770904925, 'precision': 0.5798479087452472, 'recall': 0.8789625360230547}

# %% [markdown]
# ### Metrics visualizate

# %%
metrics_for_plots = dict()

for i in range(CV_N):
    fold = f"fold{i+1}"
    path2metrics_data = f"{path2save}/{fold}/train_history.json"
    with open(path2metrics_data, 'r') as f:
        metrics = json.load(f)
    metrics_for_plots[fold] = metrics

# %%
path2save = '..\\models_checkpoints/resnet_18_backbone_cv/2026-04-23_18_17_44_full_tuning_patient'

# '..\\models_checkpoints/resnet_18_backbone_cv/2026-04-23_18_17_44_full_tuning_patient'

# %%
metrics_keys = ["totals_loss", "valids_loss", "accuracy", "balanced_accuracy", "f1", "precision", "recall"]
rows = len(metrics_keys)
cols = 1

fig, ax = plt.subplots(nrows=rows, ncols=cols, figsize=(cols * 8, rows * 4))

for i in range(rows):    

    for fold in list(metrics_for_plots.keys()):
        
        ax[i].plot(metrics_for_plots[fold][metrics_keys[i]], label=fold)

    ax[i].legend(loc='upper right', fontsize=11, framealpha=0.9)
    ax[i].set_title(metrics_keys[i])
    ax[i].grid(True)

plt.tight_layout() 
plt.show()

# %%
# === model init ===
metrics_per_folds = dict()

for i in range(CV_N):
    fold = f"fold{i+1}"
    
    path2file_fold = Path(path2save) / fold / "train_history.json"

    with open(path2file_fold, "r", encoding="utf-8") as file:
        json_file = json.loads(file.read())
    

    item_accuracy_mean = np.mean(json_file["accuracy"])    
    item_balanced_accuracy_mean = np.mean(json_file["balanced_accuracy"])
    item_f1_mean = np.mean(json_file["f1"])
    
    item_accuracy_std = np.std(json_file["accuracy"])    
    item_balanced_accuracy_std = np.std(json_file["balanced_accuracy"])
    item_f1_std = np.std(json_file["f1"])

    metrics_per_folds[fold] = {
        "accuracy": item_accuracy_mean,
        "balanced_accuracy": item_balanced_accuracy_mean,
        "f1": item_f1_mean,   
    }

    print(f'''{fold}
accuracy: {item_accuracy_mean:.3f} +- {item_accuracy_std:.3f}
balanced_accuracy: {item_balanced_accuracy_mean:.3f} +- {item_balanced_accuracy_std:.3f}
f1: {item_f1_mean:.3f} +- {item_f1_std:.3f}
''')
# Out:
# fold1
# accuracy: 0.532 +- 0.038
# balanced_accuracy: 0.580 +- 0.030
# f1: 0.573 +- 0.021
#
# fold2
# accuracy: 0.615 +- 0.017
# balanced_accuracy: 0.601 +- 0.023
# f1: 0.672 +- 0.023
#
# fold3
# accuracy: 0.630 +- 0.028
# balanced_accuracy: 0.631 +- 0.027
# f1: 0.670 +- 0.031
#
# fold4
# accuracy: 0.623 +- 0.026
# balanced_accuracy: 0.606 +- 0.030
# f1: 0.694 +- 0.014
#
# fold5
# accuracy: 0.614 +- 0.048
# balanced_accuracy: 0.611 +- 0.046
# f1: 0.641 +- 0.129

# %%
# === Финальные метрики ===
for metric in ['accuracy', 'balanced_accuracy', 'f1']:
    values = [metrics_per_folds[f][metric] for f in metrics_per_folds.keys()]
    mean_val = np.mean(values)
    std_val = np.std(values)
    print(f"{metric}: {mean_val:.3f} ± {std_val:.3f}")
# Out:
# accuracy: 0.603 ± 0.036
# balanced_accuracy: 0.606 ± 0.017
# f1: 0.650 ± 0.042
